# %%
import os
os.environ['PYTHONPATH'] = '/home/user/conda/envs/lm-exps/lib/python3.10/site-packages'
os.environ["PATH"] = '/home/user/conda/envs/lm-exps/bin'

import datasets
import json
import numpy as np
import pandas as pd
from collections import defaultdict

from sklearn.metrics import roc_auc_score
from lm_polygraph.utils.manager import UEManager, _delete_nans, _recombine_data
from lm_polygraph.ue_metrics.risk_cov_curve import RiskCoverageCurveAUC
from lm_polygraph.ue_metrics.pred_rej_area import PredictionRejectionArea
from transformers import AutoTokenizer

prr = PredictionRejectionArea()

# %% [markdown]
# # CoQA

# %% [markdown]
# ## Vicuna 7b

# %%
path = "lm-polygraph/workdir/output/qa/lmsys/vicuna-7b-v1.5/coqa/2024-04-09/22-25-24/ue_manager_seed1"
man = UEManager.load(path)

metric_names = ['Accuracy', 'AlignScore']
df = {}
for key in man.metrics.keys():
    if (key[-1] == 'prr_normalized') and (key[-2] in metric_names):
        scores = df.get(key[1], [])
        scores.append(man.metrics[key])
        df[key[1]] = scores
        
df0 = pd.DataFrame(df, index=[f'CoQA, {m}, PRR' for m in metric_names])  
df0.T.sort_values(f"CoQA, {metric_names[-1]}, PRR", ascending=False).style.background_gradient(axis=0)
# Out:
# Stat calculators: [<lm_polygraph.stat_calculators.greedy_probs.GreedyProbsCalculator object at 0x7fc48b67cf40>]
# <style type="text/css">
# #T_fa1c7_row0_col0 {
#   background-color: #0f76b3;
#   color: #f1f1f1;
# }
# #T_fa1c7_row0_col1, #T_fa1c7_row3_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_fa1c7_row1_col0 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_fa1c7_row1_col1 {
#   background-color: #045280;
#   color: #f1f1f1;
# }
# #T_fa1c7_row2_col0 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# #T_fa1c7_row2_col1, #T_fa1c7_row10_col0 {
#   background-color: #045585;
#   color: #f1f1f1;
# }
# #T_fa1c7_row3_col1, #T_fa1c7_row11_col0 {
#   background-color: #045687;
#   color: #f1f1f1;
# }
# #T_fa1c7_row4_col0, #T_fa1c7_row9_col0 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_fa1c7_row4_col1, #T_fa1c7_row5_col1, #T_fa1c7_row13_col0 {
#   background-color: #045788;
#   color: #f1f1f1;
# }
# #T_fa1c7_row5_col0 {
#   background-color: #023b5d;
#   color: #f1f1f1;
# }
# #T_fa1c7_row6_col0 {
#   background-color: #045382;
#   color: #f1f1f1;
# }
# #T_fa1c7_row6_col1, #T_fa1c7_row7_col1, #T_fa1c7_row15_col0 {
#   background-color: #04598c;
#   color: #f1f1f1;
# }
# #T_fa1c7_row7_col0, #T_fa1c7_row8_col0 {
#   background-color: #023e62;
#   color: #f1f1f1;
# }
# #T_fa1c7_row8_col1, #T_fa1c7_row14_col0 {
#   background-color: #045b8e;
#   color: #f1f1f1;
# }
# #T_fa1c7_row9_col1 {
#   background-color: #045e94;
#   color: #f1f1f1;
# }
# #T_fa1c7_row10_col1, #T_fa1c7_row16_col0 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T_fa1c7_row11_col1, #T_fa1c7_row12_col1 {
#   background-color: #04639b;
#   color: #f1f1f1;
# }
# #T_fa1c7_row12_col0 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_fa1c7_row13_col1 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_fa1c7_row14_col1 {
#   background-color: #0a73b2;
#   color: #f1f1f1;
# }
# #T_fa1c7_row15_col1 {
#   background-color: #3790c0;
#   color: #f1f1f1;
# }
# #T_fa1c7_row16_col1 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_fa1c7_row17_col0 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_fa1c7_row17_col1 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_fa1c7_row18_col0, #T_fa1c7_row18_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_fa1c7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fa1c7_level0_col0" class="col_heading level0 col0" >CoQA, Accuracy, PRR</th>
#       <th id="T_fa1c7_level0_col1" class="col_heading level0 col1" >CoQA, AlignScore, PRR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa1c7_level0_row0" class="row_heading level0 row0" >MaximumSequenceProbability</th>
#       <td id="T_fa1c7_row0_col0" class="data row0 col0" >0.485674</td>
#       <td id="T_fa1c7_row0_col1" class="data row0 col1" >0.426848</td>
#     </tr>
#     <tr>
#       <th id="T_fa1c7_level0_row1" class="row_heading level0 row1" >TokenMahalanobisDistance_decoder (mean, accuracy, 1.0)</th>
#       <td id="T_fa1c7_row1_col0" class="data row1 col0" >0.727515</td>
#       <td id="T_fa1c7_row1_col1" class="data row1 col1" >0.398484</td>
#     </tr>
#     <tr>
#       <th id="T_fa1c7_level0_row2" class="row_heading level0 row2" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.9)</th>
#       <td id="T_fa1c7_row2_col0" class="data row2 col0" >0.716602</td>
#       <td id="T_fa1c7_row2_col1" class="data row2 col1" >0.395771</td>
#     </tr>
#     <tr>
#       <th id="T_fa1c7_level0_row3" class="row_heading level0 row3" >RelativeMahalanobisDistance_decoder (sum, accuracy, 1.0)</th>
#       <td id="T_fa1c7_row3_col0" class="data row3 col0" >0.769119</td>
#       <td id="T_fa1c7_row3_col1" class="data row3 col1" >0.394056</td>
#     </tr>
#     <tr>
#       <th id="T_fa1c7_level0_row4" class="row_heading level0 row4" >RelativeMahalanobisDistance_decoder (mean, accuracy, 1.0)</th>
#       <td id="T_fa1c7_row4_col0" class="data row4 col0" >0.738503</td>
#       <td id="T_fa1c7_row4_col1" class="data row4 col1" >0.393038</td>
#     </tr>
#     <tr>
#       <th id="T_fa1c7_level0_row5" class="row_heading level0 row5" >TokenMahalanobisDistance_decoder (sum, accuracy, 1.0)</th>
#       <td id="T_fa1c7_row5_col0" class="data row5 col0" >0.755343</td>
#       <td id="T_fa1c7_row5_col1" class="data row5 col1" >0.392636</td>
#     </tr>
#     <tr>
#       <th id="T_fa1c7_level0_row6" class="row_heading level0 row6" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.9)</th>
#       <td id="T_fa1c7_row6_col0" class="data row6 col0" >0.665990</td>
#       <td id="T_fa1c7_row6_col1" class="data row6 col1" >0.391263</td>
#     </tr>
#     <tr>
#       <th id="T_fa1c7_level0_row7" class="row_heading level0 row7" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.9)</th>
#       <td id="T_fa1c7_row7_col0" class="data row7 col0" >0.744779</td>
#       <td id="T_fa1c7_row7_col1" class="data row7 col1" >0.390905</td>
#     </tr>
#     <tr>
#       <th id="T_fa1c7_level0_row8" class="row_heading level0 row8" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_fa1c7_row8_col0" class="data row8 col0" >0.743296</td>
#       <td id="T_fa1c7_row8_col1" class="data row8 col1" >0.388285</td>
#     </tr>
#     <tr>
#       <th id="T_fa1c7_level0_row9" class="row_heading level0 row9" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.0)</th>
#       <td id="T_fa1c7_row9_col0" class="data row9 col0" >0.740978</td>
#       <td id="T_fa1c7_row9_col1" class="data row9 col1" >0.383136</td>
#     </tr>
#     <tr>
#       <th id="T_fa1c7_level0_row10" class="row_heading level0 row10" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_fa1c7_row10_col0" class="data row10 col0" >0.656842</td>
#       <td id="T_fa1c7_row10_col1" class="data row10 col1" >0.381683</td>
#     </tr>
#     <tr>
#       <th id="T_fa1c7_level0_row11" class="row_heading level0 row11" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.9)</th>
#       <td id="T_fa1c7_row11_col0" class="data row11 col0" >0.656039</td>
#       <td id="T_fa1c7_row11_col1" class="data row11 col1" >0.374840</td>
#     </tr>
#     <tr>
#       <th id="T_fa1c7_level0_row12" class="row_heading level0 row12" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_fa1c7_row12_col0" class="data row12 col0" >0.691365</td>
#       <td id="T_fa1c7_row12_col1" class="data row12 col1" >0.374688</td>
#     </tr>
#     <tr>
#       <th id="T_fa1c7_level0_row13" class="row_heading level0 row13" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_fa1c7_row13_col0" class="data row13 col0" >0.649129</td>
#       <td id="T_fa1c7_row13_col1" class="data row13 col1" >0.364567</td>
#     </tr>
#     <tr>
#       <th id="T_fa1c7_level0_row14" class="row_heading level0 row14" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_fa1c7_row14_col0" class="data row14 col0" >0.633675</td>
#       <td id="T_fa1c7_row14_col1" class="data row14 col1" >0.349633</td>
#     </tr>
#     <tr>
#       <th id="T_fa1c7_level0_row15" class="row_heading level0 row15" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.0)</th>
#       <td id="T_fa1c7_row15_col0" class="data row15 col0" >0.644146</td>
#       <td id="T_fa1c7_row15_col1" class="data row15 col1" >0.316519</td>
#     </tr>
#     <tr>
#       <th id="T_fa1c7_level0_row16" class="row_heading level0 row16" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_fa1c7_row16_col0" class="data row16 col0" >0.611307</td>
#       <td id="T_fa1c7_row16_col1" class="data row16 col1" >0.311650</td>
#     </tr>
#     <tr>
#       <th id="T_fa1c7_level0_row17" class="row_heading level0 row17" >Perplexity</th>
#       <td id="T_fa1c7_row17_col0" class="data row17 col0" >-0.167092</td>
#       <td id="T_fa1c7_row17_col1" class="data row17 col1" >0.154601</td>
#     </tr>
#     <tr>
#       <th id="T_fa1c7_level0_row18" class="row_heading level0 row18" >MeanTokenEntropy</th>
#       <td id="T_fa1c7_row18_col0" class="data row18 col0" >-0.258534</td>
#       <td id="T_fa1c7_row18_col1" class="data row18 col1" >0.134364</td>
#     </tr>
#   </tbody>
# </table>

# %%
np.mean(man.gen_metrics[('sequence', 'Accuracy')])
# Out:
# 0.311

# %% [markdown]
# ## Vicuna-13b

# %%
path = "lm-polygraph/workdir/output/qa/lmsys/vicuna-13b-v1.5/coqa/2024-04-09/22-25-46/ue_manager_seed1"
man = UEManager.load(path)

metric_names = ['Accuracy', 'AlignScore']
df = {}
for key in man.metrics.keys():
    if (key[-1] == 'prr_normalized') and (key[-2] in metric_names):
        scores = df.get(key[1], [])
        scores.append(man.metrics[key])
        df[key[1]] = scores
        
df0 = pd.DataFrame(df, index=[f'CoQA, {m}, PRR' for m in metric_names])  
df0.T.sort_values(f"CoQA, {metric_names[-1]}, PRR", ascending=False).style.background_gradient(axis=0)
# Out:
# Stat calculators: [<lm_polygraph.stat_calculators.greedy_probs.GreedyProbsCalculator object at 0x7fc48b67cf40>]
# <style type="text/css">
# #T_964a1_row0_col0 {
#   background-color: #04639b;
#   color: #f1f1f1;
# }
# #T_964a1_row0_col1, #T_964a1_row5_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_964a1_row1_col0 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# #T_964a1_row1_col1 {
#   background-color: #04629a;
#   color: #f1f1f1;
# }
# #T_964a1_row2_col0 {
#   background-color: #045e93;
#   color: #f1f1f1;
# }
# #T_964a1_row2_col1, #T_964a1_row16_col0 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_964a1_row3_col0, #T_964a1_row12_col0 {
#   background-color: #034267;
#   color: #f1f1f1;
# }
# #T_964a1_row3_col1 {
#   background-color: #0872b1;
#   color: #f1f1f1;
# }
# #T_964a1_row4_col0 {
#   background-color: #046097;
#   color: #f1f1f1;
# }
# #T_964a1_row4_col1 {
#   background-color: #0a73b2;
#   color: #f1f1f1;
# }
# #T_964a1_row5_col1 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_964a1_row6_col0 {
#   background-color: #04598c;
#   color: #f1f1f1;
# }
# #T_964a1_row6_col1 {
#   background-color: #4496c3;
#   color: #f1f1f1;
# }
# #T_964a1_row7_col0 {
#   background-color: #04649d;
#   color: #f1f1f1;
# }
# #T_964a1_row7_col1 {
#   background-color: #4697c4;
#   color: #f1f1f1;
# }
# #T_964a1_row8_col0 {
#   background-color: #045d92;
#   color: #f1f1f1;
# }
# #T_964a1_row8_col1 {
#   background-color: #4a98c5;
#   color: #f1f1f1;
# }
# #T_964a1_row9_col0 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_964a1_row9_col1 {
#   background-color: #569dc8;
#   color: #f1f1f1;
# }
# #T_964a1_row10_col0 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_964a1_row10_col1 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_964a1_row11_col0 {
#   background-color: #034165;
#   color: #f1f1f1;
# }
# #T_964a1_row11_col1 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_964a1_row12_col1 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_964a1_row13_col0 {
#   background-color: #046198;
#   color: #f1f1f1;
# }
# #T_964a1_row13_col1 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_964a1_row14_col0 {
#   background-color: #0567a1;
#   color: #f1f1f1;
# }
# #T_964a1_row14_col1 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_964a1_row15_col0, #T_964a1_row18_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_964a1_row15_col1 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_964a1_row16_col1 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_964a1_row17_col0 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_964a1_row17_col1 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_964a1_row18_col0 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_964a1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_964a1_level0_col0" class="col_heading level0 col0" >CoQA, Accuracy, PRR</th>
#       <th id="T_964a1_level0_col1" class="col_heading level0 col1" >CoQA, AlignScore, PRR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_964a1_level0_row0" class="row_heading level0 row0" >MaximumSequenceProbability</th>
#       <td id="T_964a1_row0_col0" class="data row0 col0" >0.571644</td>
#       <td id="T_964a1_row0_col1" class="data row0 col1" >0.476971</td>
#     </tr>
#     <tr>
#       <th id="T_964a1_level0_row1" class="row_heading level0 row1" >TokenMahalanobisDistance_decoder (mean, accuracy, 1.0)</th>
#       <td id="T_964a1_row1_col0" class="data row1 col0" >0.669625</td>
#       <td id="T_964a1_row1_col1" class="data row1 col1" >0.424662</td>
#     </tr>
#     <tr>
#       <th id="T_964a1_level0_row2" class="row_heading level0 row2" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.9)</th>
#       <td id="T_964a1_row2_col0" class="data row2 col0" >0.594895</td>
#       <td id="T_964a1_row2_col1" class="data row2 col1" >0.415991</td>
#     </tr>
#     <tr>
#       <th id="T_964a1_level0_row3" class="row_heading level0 row3" >RelativeMahalanobisDistance_decoder (mean, accuracy, 1.0)</th>
#       <td id="T_964a1_row3_col0" class="data row3 col0" >0.682688</td>
#       <td id="T_964a1_row3_col1" class="data row3 col1" >0.398452</td>
#     </tr>
#     <tr>
#       <th id="T_964a1_level0_row4" class="row_heading level0 row4" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_964a1_row4_col0" class="data row4 col0" >0.582878</td>
#       <td id="T_964a1_row4_col1" class="data row4 col1" >0.397330</td>
#     </tr>
#     <tr>
#       <th id="T_964a1_level0_row5" class="row_heading level0 row5" >RelativeMahalanobisDistance_decoder (sum, accuracy, 1.0)</th>
#       <td id="T_964a1_row5_col0" class="data row5 col0" >0.711412</td>
#       <td id="T_964a1_row5_col1" class="data row5 col1" >0.355334</td>
#     </tr>
#     <tr>
#       <th id="T_964a1_level0_row6" class="row_heading level0 row6" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.9)</th>
#       <td id="T_964a1_row6_col0" class="data row6 col0" >0.614735</td>
#       <td id="T_964a1_row6_col1" class="data row6 col1" >0.354281</td>
#     </tr>
#     <tr>
#       <th id="T_964a1_level0_row7" class="row_heading level0 row7" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_964a1_row7_col0" class="data row7 col0" >0.568651</td>
#       <td id="T_964a1_row7_col1" class="data row7 col1" >0.353172</td>
#     </tr>
#     <tr>
#       <th id="T_964a1_level0_row8" class="row_heading level0 row8" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.9)</th>
#       <td id="T_964a1_row8_col0" class="data row8 col0" >0.598521</td>
#       <td id="T_964a1_row8_col1" class="data row8 col1" >0.350778</td>
#     </tr>
#     <tr>
#       <th id="T_964a1_level0_row9" class="row_heading level0 row9" >TokenMahalanobisDistance_decoder (sum, accuracy, 1.0)</th>
#       <td id="T_964a1_row9_col0" class="data row9 col0" >0.698367</td>
#       <td id="T_964a1_row9_col1" class="data row9 col1" >0.344116</td>
#     </tr>
#     <tr>
#       <th id="T_964a1_level0_row10" class="row_heading level0 row10" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.9)</th>
#       <td id="T_964a1_row10_col0" class="data row10 col0" >0.687746</td>
#       <td id="T_964a1_row10_col1" class="data row10 col1" >0.339171</td>
#     </tr>
#     <tr>
#       <th id="T_964a1_level0_row11" class="row_heading level0 row11" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_964a1_row11_col0" class="data row11 col0" >0.686505</td>
#       <td id="T_964a1_row11_col1" class="data row11 col1" >0.336789</td>
#     </tr>
#     <tr>
#       <th id="T_964a1_level0_row12" class="row_heading level0 row12" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.0)</th>
#       <td id="T_964a1_row12_col0" class="data row12 col0" >0.683397</td>
#       <td id="T_964a1_row12_col1" class="data row12 col1" >0.327864</td>
#     </tr>
#     <tr>
#       <th id="T_964a1_level0_row13" class="row_heading level0 row13" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_964a1_row13_col0" class="data row13 col0" >0.579172</td>
#       <td id="T_964a1_row13_col1" class="data row13 col1" >0.317374</td>
#     </tr>
#     <tr>
#       <th id="T_964a1_level0_row14" class="row_heading level0 row14" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_964a1_row14_col0" class="data row14 col0" >0.555075</td>
#       <td id="T_964a1_row14_col1" class="data row14 col1" >0.313009</td>
#     </tr>
#     <tr>
#       <th id="T_964a1_level0_row15" class="row_heading level0 row15" >MeanTokenEntropy</th>
#       <td id="T_964a1_row15_col0" class="data row15 col0" >-0.081245</td>
#       <td id="T_964a1_row15_col1" class="data row15 col1" >0.252261</td>
#     </tr>
#     <tr>
#       <th id="T_964a1_level0_row16" class="row_heading level0 row16" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_964a1_row16_col0" class="data row16 col0" >0.551573</td>
#       <td id="T_964a1_row16_col1" class="data row16 col1" >0.251622</td>
#     </tr>
#     <tr>
#       <th id="T_964a1_level0_row17" class="row_heading level0 row17" >Perplexity</th>
#       <td id="T_964a1_row17_col0" class="data row17 col0" >-0.042892</td>
#       <td id="T_964a1_row17_col1" class="data row17 col1" >0.248876</td>
#     </tr>
#     <tr>

# %%
np.mean(man.gen_metrics[('sequence', 'Accuracy')])
# Out:
# 0.398

# %% [markdown]
# ## Mistral 7b

# %%
path = "lm-polygraph/workdir/output/qa/alpindale/Mistral-7B-v0.2-hf/coqa/2024-04-10/05-00-05/ue_manager_seed1"
man = UEManager.load(path)

metric_names = ['Accuracy', 'AlignScore']
df = {}
for key in man.metrics.keys():
    if (key[-1] == 'prr_normalized') and (key[-2] in metric_names):
        scores = df.get(key[1], [])
        scores.append(man.metrics[key])
        df[key[1]] = scores
        
df0 = pd.DataFrame(df, index=[f'CoQA, {m}, PRR' for m in metric_names])  
df0.T.sort_values(f"CoQA, {metric_names[-1]}, PRR", ascending=False).style.background_gradient(axis=0)
# Out:
# Stat calculators: [<lm_polygraph.stat_calculators.greedy_probs.GreedyProbsCalculator object at 0x7fc48b67cf40>]
# <style type="text/css">
# #T_a3a07_row0_col0 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_a3a07_row0_col1, #T_a3a07_row8_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_a3a07_row1_col0 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_a3a07_row1_col1 {
#   background-color: #023a5b;
#   color: #f1f1f1;
# }
# #T_a3a07_row2_col0, #T_a3a07_row17_col1, #T_a3a07_row18_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_a3a07_row2_col1 {
#   background-color: #03476f;
#   color: #f1f1f1;
# }
# #T_a3a07_row3_col0 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_a3a07_row3_col1 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_a3a07_row4_col0 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_a3a07_row4_col1 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_a3a07_row5_col0 {
#   background-color: #045b8f;
#   color: #f1f1f1;
# }
# #T_a3a07_row5_col1 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_a3a07_row6_col0 {
#   background-color: #023e62;
#   color: #f1f1f1;
# }
# #T_a3a07_row6_col1 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_a3a07_row7_col0 {
#   background-color: #03456c;
#   color: #f1f1f1;
# }
# #T_a3a07_row7_col1 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_a3a07_row8_col1 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_a3a07_row9_col0 {
#   background-color: #1379b5;
#   color: #f1f1f1;
# }
# #T_a3a07_row9_col1 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_a3a07_row10_col0, #T_a3a07_row11_col0 {
#   background-color: #0566a0;
#   color: #f1f1f1;
# }
# #T_a3a07_row10_col1 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_a3a07_row11_col1 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_a3a07_row12_col0 {
#   background-color: #157ab5;
#   color: #f1f1f1;
# }
# #T_a3a07_row12_col1 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_a3a07_row13_col0, #T_a3a07_row14_col0 {
#   background-color: #034e7b;
#   color: #f1f1f1;
# }
# #T_a3a07_row13_col1 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_a3a07_row14_col1, #T_a3a07_row15_col1 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_a3a07_row15_col0, #T_a3a07_row16_col0 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T_a3a07_row16_col1 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_a3a07_row17_col0 {
#   background-color: #3790c0;
#   color: #f1f1f1;
# }
# #T_a3a07_row18_col0 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a3a07">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a3a07_level0_col0" class="col_heading level0 col0" >CoQA, Accuracy, PRR</th>
#       <th id="T_a3a07_level0_col1" class="col_heading level0 col1" >CoQA, AlignScore, PRR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a3a07_level0_row0" class="row_heading level0 row0" >MaximumSequenceProbability</th>
#       <td id="T_a3a07_row0_col0" class="data row0 col0" >0.085285</td>
#       <td id="T_a3a07_row0_col1" class="data row0 col1" >0.225358</td>
#     </tr>
#     <tr>
#       <th id="T_a3a07_level0_row1" class="row_heading level0 row1" >Perplexity</th>
#       <td id="T_a3a07_row1_col0" class="data row1 col0" >0.086268</td>
#       <td id="T_a3a07_row1_col1" class="data row1 col1" >0.221819</td>
#     </tr>
#     <tr>
#       <th id="T_a3a07_level0_row2" class="row_heading level0 row2" >MeanTokenEntropy</th>
#       <td id="T_a3a07_row2_col0" class="data row2 col0" >0.061717</td>
#       <td id="T_a3a07_row2_col1" class="data row2 col1" >0.205033</td>
#     </tr>
#     <tr>
#       <th id="T_a3a07_level0_row3" class="row_heading level0 row3" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.9)</th>
#       <td id="T_a3a07_row3_col0" class="data row3 col0" >0.225555</td>
#       <td id="T_a3a07_row3_col1" class="data row3 col1" >0.001932</td>
#     </tr>
#     <tr>
#       <th id="T_a3a07_level0_row4" class="row_heading level0 row4" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_a3a07_row4_col0" class="data row4 col0" >0.241225</td>
#       <td id="T_a3a07_row4_col1" class="data row4 col1" >-0.004349</td>
#     </tr>
#     <tr>
#       <th id="T_a3a07_level0_row5" class="row_heading level0 row5" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.9)</th>
#       <td id="T_a3a07_row5_col0" class="data row5 col0" >0.229649</td>
#       <td id="T_a3a07_row5_col1" class="data row5 col1" >-0.006377</td>
#     </tr>
#     <tr>
#       <th id="T_a3a07_level0_row6" class="row_heading level0 row6" >TokenMahalanobisDistance_decoder (sum, accuracy, 1.0)</th>
#       <td id="T_a3a07_row6_col0" class="data row6 col0" >0.251100</td>
#       <td id="T_a3a07_row6_col1" class="data row6 col1" >-0.009197</td>
#     </tr>
#     <tr>
#       <th id="T_a3a07_level0_row7" class="row_heading level0 row7" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_a3a07_row7_col0" class="data row7 col0" >0.246404</td>
#       <td id="T_a3a07_row7_col1" class="data row7 col1" >-0.011738</td>
#     </tr>
#     <tr>
#       <th id="T_a3a07_level0_row8" class="row_heading level0 row8" >TokenMahalanobisDistance_decoder (mean, accuracy, 1.0)</th>
#       <td id="T_a3a07_row8_col0" class="data row8 col0" >0.256077</td>
#       <td id="T_a3a07_row8_col1" class="data row8 col1" >-0.016848</td>
#     </tr>
#     <tr>
#       <th id="T_a3a07_level0_row9" class="row_heading level0 row9" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.0)</th>
#       <td id="T_a3a07_row9_col0" class="data row9 col0" >0.199988</td>
#       <td id="T_a3a07_row9_col1" class="data row9 col1" >-0.056343</td>
#     </tr>
#     <tr>
#       <th id="T_a3a07_level0_row10" class="row_heading level0 row10" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.9)</th>
#       <td id="T_a3a07_row10_col0" class="data row10 col0" >0.218246</td>
#       <td id="T_a3a07_row10_col1" class="data row10 col1" >-0.064008</td>
#     </tr>
#     <tr>
#       <th id="T_a3a07_level0_row11" class="row_heading level0 row11" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.9)</th>
#       <td id="T_a3a07_row11_col0" class="data row11 col0" >0.218458</td>
#       <td id="T_a3a07_row11_col1" class="data row11 col1" >-0.065398</td>
#     </tr>
#     <tr>
#       <th id="T_a3a07_level0_row12" class="row_heading level0 row12" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_a3a07_row12_col0" class="data row12 col0" >0.199571</td>
#       <td id="T_a3a07_row12_col1" class="data row12 col1" >-0.071432</td>
#     </tr>
#     <tr>
#       <th id="T_a3a07_level0_row13" class="row_heading level0 row13" >RelativeMahalanobisDistance_decoder (sum, accuracy, 1.0)</th>
#       <td id="T_a3a07_row13_col0" class="data row13 col0" >0.239476</td>
#       <td id="T_a3a07_row13_col1" class="data row13 col1" >-0.078789</td>
#     </tr>
#     <tr>
#       <th id="T_a3a07_level0_row14" class="row_heading level0 row14" >RelativeMahalanobisDistance_decoder (mean, accuracy, 1.0)</th>
#       <td id="T_a3a07_row14_col0" class="data row14 col0" >0.239650</td>
#       <td id="T_a3a07_row14_col1" class="data row14 col1" >-0.079976</td>
#     </tr>
#     <tr>
#       <th id="T_a3a07_level0_row15" class="row_heading level0 row15" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_a3a07_row15_col0" class="data row15 col0" >0.226188</td>
#       <td id="T_a3a07_row15_col1" class="data row15 col1" >-0.081424</td>
#     </tr>
#     <tr>
#       <th id="T_a3a07_level0_row16" class="row_heading level0 row16" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_a3a07_row16_col0" class="data row16 col0" >0.226289</td>
#       <td id="T_a3a07_row16_col1" class="data row16 col1" >-0.082289</td>
#     </tr>
#     <tr>
#       <th id="T_a3a07_level0_row17" class="row_heading level0 row17" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.0)</th>
#       <td id="T_a3a07_row17_col0" class="data row17 col0" >0.183192</td>
#       <td id="T_a3a07_row17_col1" class="data row17 col1" >-0.133021</td>
#     </tr>
#     <tr>
#       <th id="T_a3a07_level0_row18" class="row_heading level0 row18" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>

# %%
np.mean(man.gen_metrics[('sequence', 'Accuracy')])
# Out:
# 0.5705

# %% [markdown]
# # SciQ

# %% [markdown]
# ## Vicuna 7b

# %%
path = "lm-polygraph/workdir/output/qa/lmsys/vicuna-7b-v1.5/sciq/2024-04-09/22-25-46/ue_manager_seed1"
man = UEManager.load(path)

metric_names = ['Accuracy', 'AlignScore']
df = {}
for key in man.metrics.keys():
    if (key[-1] == 'prr_normalized') and (key[-2] in metric_names):
        scores = df.get(key[1], [])
        scores.append(man.metrics[key])
        df[key[1]] = scores
        
df0 = pd.DataFrame(df, index=[f'SciQ, {m}, PRR' for m in metric_names])  
df0.T.sort_values(f"SciQ, {metric_names[-1]}, PRR", ascending=False).style.background_gradient(axis=0)
# Out:
# Stat calculators: [<lm_polygraph.stat_calculators.greedy_probs.GreedyProbsCalculator object at 0x7fc48b67cf40>]
# <style type="text/css">
# #T_717b3_row0_col0 {
#   background-color: #05659f;
#   color: #f1f1f1;
# }
# #T_717b3_row0_col1, #T_717b3_row8_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_717b3_row1_col0 {
#   background-color: #0568a3;
#   color: #f1f1f1;
# }
# #T_717b3_row1_col1 {
#   background-color: #034165;
#   color: #f1f1f1;
# }
# #T_717b3_row2_col0, #T_717b3_row5_col0 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_717b3_row2_col1 {
#   background-color: #034267;
#   color: #f1f1f1;
# }
# #T_717b3_row3_col0, #T_717b3_row9_col1, #T_717b3_row10_col1 {
#   background-color: #046198;
#   color: #f1f1f1;
# }
# #T_717b3_row3_col1, #T_717b3_row4_col1 {
#   background-color: #034a74;
#   color: #f1f1f1;
# }
# #T_717b3_row4_col0 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_717b3_row5_col1 {
#   background-color: #034b76;
#   color: #f1f1f1;
# }
# #T_717b3_row6_col0 {
#   background-color: #056aa6;
#   color: #f1f1f1;
# }
# #T_717b3_row6_col1 {
#   background-color: #045382;
#   color: #f1f1f1;
# }
# #T_717b3_row7_col0 {
#   background-color: #023e62;
#   color: #f1f1f1;
# }
# #T_717b3_row7_col1 {
#   background-color: #045e94;
#   color: #f1f1f1;
# }
# #T_717b3_row8_col1 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T_717b3_row9_col0 {
#   background-color: #02395a;
#   color: #f1f1f1;
# }
# #T_717b3_row10_col0, #T_717b3_row12_col0 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_717b3_row11_col0 {
#   background-color: #2081b9;
#   color: #f1f1f1;
# }
# #T_717b3_row11_col1, #T_717b3_row12_col1 {
#   background-color: #04639b;
#   color: #f1f1f1;
# }
# #T_717b3_row13_col0 {
#   background-color: #0570b0;
#   color: #f1f1f1;
# }
# #T_717b3_row13_col1 {
#   background-color: #04649d;
#   color: #f1f1f1;
# }
# #T_717b3_row14_col0 {
#   background-color: #0d75b3;
#   color: #f1f1f1;
# }
# #T_717b3_row14_col1 {
#   background-color: #157ab5;
#   color: #f1f1f1;
# }
# #T_717b3_row15_col0 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_717b3_row15_col1 {
#   background-color: #3d93c2;
#   color: #f1f1f1;
# }
# #T_717b3_row16_col0 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_717b3_row16_col1 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_717b3_row17_col0 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_717b3_row17_col1, #T_717b3_row18_col0, #T_717b3_row18_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_717b3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_717b3_level0_col0" class="col_heading level0 col0" >SciQ, Accuracy, PRR</th>
#       <th id="T_717b3_level0_col1" class="col_heading level0 col1" >SciQ, AlignScore, PRR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_717b3_level0_row0" class="row_heading level0 row0" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.9)</th>
#       <td id="T_717b3_row0_col0" class="data row0 col0" >0.665993</td>
#       <td id="T_717b3_row0_col1" class="data row0 col1" >0.584277</td>
#     </tr>
#     <tr>
#       <th id="T_717b3_level0_row1" class="row_heading level0 row1" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_717b3_row1_col0" class="data row1 col0" >0.644520</td>
#       <td id="T_717b3_row1_col1" class="data row1 col1" >0.566720</td>
#     </tr>
#     <tr>
#       <th id="T_717b3_level0_row2" class="row_heading level0 row2" >TokenMahalanobisDistance_decoder (mean, accuracy, 1.0)</th>
#       <td id="T_717b3_row2_col0" class="data row2 col0" >0.902777</td>
#       <td id="T_717b3_row2_col1" class="data row2 col1" >0.564961</td>
#     </tr>
#     <tr>
#       <th id="T_717b3_level0_row3" class="row_heading level0 row3" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.9)</th>
#       <td id="T_717b3_row3_col0" class="data row3 col0" >0.697955</td>
#       <td id="T_717b3_row3_col1" class="data row3 col1" >0.550695</td>
#     </tr>
#     <tr>
#       <th id="T_717b3_level0_row4" class="row_heading level0 row4" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_717b3_row4_col0" class="data row4 col0" >0.635907</td>
#       <td id="T_717b3_row4_col1" class="data row4 col1" >0.549770</td>
#     </tr>
#     <tr>
#       <th id="T_717b3_level0_row5" class="row_heading level0 row5" >RelativeMahalanobisDistance_decoder (mean, accuracy, 1.0)</th>
#       <td id="T_717b3_row5_col0" class="data row5 col0" >0.905488</td>
#       <td id="T_717b3_row5_col1" class="data row5 col1" >0.548268</td>
#     </tr>
#     <tr>
#       <th id="T_717b3_level0_row6" class="row_heading level0 row6" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.9)</th>
#       <td id="T_717b3_row6_col0" class="data row6 col0" >0.629997</td>
#       <td id="T_717b3_row6_col1" class="data row6 col1" >0.534538</td>
#     </tr>
#     <tr>
#       <th id="T_717b3_level0_row7" class="row_heading level0 row7" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.9)</th>
#       <td id="T_717b3_row7_col0" class="data row7 col0" >0.890280</td>
#       <td id="T_717b3_row7_col1" class="data row7 col1" >0.507877</td>
#     </tr>
#     <tr>
#       <th id="T_717b3_level0_row8" class="row_heading level0 row8" >RelativeMahalanobisDistance_decoder (sum, accuracy, 1.0)</th>
#       <td id="T_717b3_row8_col0" class="data row8 col0" >0.927680</td>
#       <td id="T_717b3_row8_col1" class="data row8 col1" >0.506569</td>
#     </tr>
#     <tr>
#       <th id="T_717b3_level0_row9" class="row_heading level0 row9" >TokenMahalanobisDistance_decoder (sum, accuracy, 1.0)</th>
#       <td id="T_717b3_row9_col0" class="data row9 col0" >0.920234</td>
#       <td id="T_717b3_row9_col1" class="data row9 col1" >0.501223</td>
#     </tr>
#     <tr>
#       <th id="T_717b3_level0_row10" class="row_heading level0 row10" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_717b3_row10_col0" class="data row10 col0" >0.886537</td>
#       <td id="T_717b3_row10_col1" class="data row10 col1" >0.501003</td>
#     </tr>
#     <tr>
#       <th id="T_717b3_level0_row11" class="row_heading level0 row11" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_717b3_row11_col0" class="data row11 col0" >0.493983</td>
#       <td id="T_717b3_row11_col1" class="data row11 col1" >0.494714</td>
#     </tr>
#     <tr>
#       <th id="T_717b3_level0_row12" class="row_heading level0 row12" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.0)</th>
#       <td id="T_717b3_row12_col0" class="data row12 col0" >0.885171</td>
#       <td id="T_717b3_row12_col1" class="data row12 col1" >0.494676</td>
#     </tr>
#     <tr>
#       <th id="T_717b3_level0_row13" class="row_heading level0 row13" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_717b3_row13_col0" class="data row13 col0" >0.584111</td>
#       <td id="T_717b3_row13_col1" class="data row13 col1" >0.492121</td>
#     </tr>
#     <tr>
#       <th id="T_717b3_level0_row14" class="row_heading level0 row14" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_717b3_row14_col0" class="data row14 col0" >0.557236</td>
#       <td id="T_717b3_row14_col1" class="data row14 col1" >0.437901</td>
#     </tr>
#     <tr>
#       <th id="T_717b3_level0_row15" class="row_heading level0 row15" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.0)</th>
#       <td id="T_717b3_row15_col0" class="data row15 col0" >0.309544</td>
#       <td id="T_717b3_row15_col1" class="data row15 col1" >0.388532</td>
#     </tr>
#     <tr>
#       <th id="T_717b3_level0_row16" class="row_heading level0 row16" >MaximumSequenceProbability</th>
#       <td id="T_717b3_row16_col0" class="data row16 col0" >-0.027140</td>
#       <td id="T_717b3_row16_col1" class="data row16 col1" >0.259969</td>
#     </tr>
#     <tr>
#       <th id="T_717b3_level0_row17" class="row_heading level0 row17" >Perplexity</th>
#       <td id="T_717b3_row17_col0" class="data row17 col0" >-0.382478</td>
#       <td id="T_717b3_row17_col1" class="data row17 col1" >0.079266</td>
#     </tr>
#     <tr>
#       <th id="T_717b3_level0_row18" class="row_heading level0 row18" >MeanTokenEntropy</th>
#       <td id="T_717b3_row18_col0" class="data row18 col0" >-0.442261</td>
#       <td id="T_717b3_row18_col1" class="

# %%
np.mean(man.gen_metrics[('sequence', 'Accuracy')])
# Out:
# 0.211

# %% [markdown]
# ## Vicuna 13b

# %%
path = "lm-polygraph/workdir/output/qa/lmsys/vicuna-13b-v1.5/sciq/2024-04-09/22-25-26/ue_manager_seed1"
man = UEManager.load(path)

metric_names = ['Accuracy', 'AlignScore']
df = {}
for key in man.metrics.keys():
    if (key[-1] == 'prr_normalized') and (key[-2] in metric_names):
        scores = df.get(key[1], [])
        scores.append(man.metrics[key])
        df[key[1]] = scores
        
df0 = pd.DataFrame(df, index=[f'SciQ, {m}, PRR' for m in metric_names])  
df0.T.sort_values(f"SciQ, {metric_names[-1]}, PRR", ascending=False).style.background_gradient(axis=0)
# Out:
# Stat calculators: [<lm_polygraph.stat_calculators.greedy_probs.GreedyProbsCalculator object at 0x7fc48b67cf40>]
# <style type="text/css">
# #T_d5821_row0_col0 {
#   background-color: #04588a;
#   color: #f1f1f1;
# }
# #T_d5821_row0_col1, #T_d5821_row8_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_d5821_row1_col0 {
#   background-color: #023e62;
#   color: #f1f1f1;
# }
# #T_d5821_row1_col1 {
#   background-color: #023d60;
#   color: #f1f1f1;
# }
# #T_d5821_row2_col0, #T_d5821_row9_col0 {
#   background-color: #045e93;
#   color: #f1f1f1;
# }
# #T_d5821_row2_col1 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_d5821_row3_col0 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_d5821_row3_col1 {
#   background-color: #03456c;
#   color: #f1f1f1;
# }
# #T_d5821_row4_col0 {
#   background-color: #03517e;
#   color: #f1f1f1;
# }
# #T_d5821_row4_col1, #T_d5821_row6_col0, #T_d5821_row14_col0 {
#   background-color: #034b76;
#   color: #f1f1f1;
# }
# #T_d5821_row5_col0 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_d5821_row5_col1, #T_d5821_row15_col0 {
#   background-color: #034d79;
#   color: #f1f1f1;
# }
# #T_d5821_row6_col1 {
#   background-color: #045687;
#   color: #f1f1f1;
# }
# #T_d5821_row7_col0 {
#   background-color: #045788;
#   color: #f1f1f1;
# }
# #T_d5821_row7_col1, #T_d5821_row10_col0 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_d5821_row8_col1 {
#   background-color: #045b8f;
#   color: #f1f1f1;
# }
# #T_d5821_row9_col1 {
#   background-color: #04639b;
#   color: #f1f1f1;
# }
# #T_d5821_row10_col1 {
#   background-color: #04649d;
#   color: #f1f1f1;
# }
# #T_d5821_row11_col0 {
#   background-color: #034267;
#   color: #f1f1f1;
# }
# #T_d5821_row11_col1 {
#   background-color: #0570b0;
#   color: #f1f1f1;
# }
# #T_d5821_row12_col0 {
#   background-color: #187cb6;
#   color: #f1f1f1;
# }
# #T_d5821_row12_col1 {
#   background-color: #0872b1;
#   color: #f1f1f1;
# }
# #T_d5821_row13_col0 {
#   background-color: #056ba9;
#   color: #f1f1f1;
# }
# #T_d5821_row13_col1 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_d5821_row14_col1 {
#   background-color: #1379b5;
#   color: #f1f1f1;
# }
# #T_d5821_row15_col1 {
#   background-color: #1b7eb7;
#   color: #f1f1f1;
# }
# #T_d5821_row16_col0 {
#   background-color: #034f7d;
#   color: #f1f1f1;
# }
# #T_d5821_row16_col1 {
#   background-color: #2383ba;
#   color: #f1f1f1;
# }
# #T_d5821_row17_col0 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_d5821_row17_col1 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_d5821_row18_col0, #T_d5821_row18_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_d5821">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d5821_level0_col0" class="col_heading level0 col0" >SciQ, Accuracy, PRR</th>
#       <th id="T_d5821_level0_col1" class="col_heading level0 col1" >SciQ, AlignScore, PRR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d5821_level0_row0" class="row_heading level0 row0" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.9)</th>
#       <td id="T_d5821_row0_col0" class="data row0 col0" >0.673459</td>
#       <td id="T_d5821_row0_col1" class="data row0 col1" >0.698069</td>
#     </tr>
#     <tr>
#       <th id="T_d5821_level0_row1" class="row_heading level0 row1" >TokenMahalanobisDistance_decoder (mean, accuracy, 1.0)</th>
#       <td id="T_d5821_row1_col0" class="data row1 col0" >0.763938</td>
#       <td id="T_d5821_row1_col1" class="data row1 col1" >0.687435</td>
#     </tr>
#     <tr>
#       <th id="T_d5821_level0_row2" class="row_heading level0 row2" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_d5821_row2_col0" class="data row2 col0" >0.649234</td>
#       <td id="T_d5821_row2_col1" class="data row2 col1" >0.681515</td>
#     </tr>
#     <tr>
#       <th id="T_d5821_level0_row3" class="row_heading level0 row3" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_d5821_row3_col0" class="data row3 col0" >0.637699</td>
#       <td id="T_d5821_row3_col1" class="data row3 col1" >0.670883</td>
#     </tr>
#     <tr>
#       <th id="T_d5821_level0_row4" class="row_heading level0 row4" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.9)</th>
#       <td id="T_d5821_row4_col0" class="data row4 col0" >0.701557</td>
#       <td id="T_d5821_row4_col1" class="data row4 col1" >0.658282</td>
#     </tr>
#     <tr>
#       <th id="T_d5821_level0_row5" class="row_heading level0 row5" >RelativeMahalanobisDistance_decoder (mean, accuracy, 1.0)</th>
#       <td id="T_d5821_row5_col0" class="data row5 col0" >0.770314</td>
#       <td id="T_d5821_row5_col1" class="data row5 col1" >0.655360</td>
#     </tr>
#     <tr>
#       <th id="T_d5821_level0_row6" class="row_heading level0 row6" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.9)</th>
#       <td id="T_d5821_row6_col0" class="data row6 col0" >0.717094</td>
#       <td id="T_d5821_row6_col1" class="data row6 col1" >0.637501</td>
#     </tr>
#     <tr>
#       <th id="T_d5821_level0_row7" class="row_heading level0 row7" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_d5821_row7_col0" class="data row7 col0" >0.678222</td>
#       <td id="T_d5821_row7_col1" class="data row7 col1" >0.630164</td>
#     </tr>
#     <tr>
#       <th id="T_d5821_level0_row8" class="row_heading level0 row8" >RelativeMahalanobisDistance_decoder (sum, accuracy, 1.0)</th>
#       <td id="T_d5821_row8_col0" class="data row8 col0" >0.787178</td>
#       <td id="T_d5821_row8_col1" class="data row8 col1" >0.626080</td>
#     </tr>
#     <tr>
#       <th id="T_d5821_level0_row9" class="row_heading level0 row9" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_d5821_row9_col0" class="data row9 col0" >0.650041</td>
#       <td id="T_d5821_row9_col1" class="data row9 col1" >0.603264</td>
#     </tr>
#     <tr>
#       <th id="T_d5821_level0_row10" class="row_heading level0 row10" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_d5821_row10_col0" class="data row10 col0" >0.666016</td>
#       <td id="T_d5821_row10_col1" class="data row10 col1" >0.600931</td>
#     </tr>
#     <tr>
#       <th id="T_d5821_level0_row11" class="row_heading level0 row11" >TokenMahalanobisDistance_decoder (sum, accuracy, 1.0)</th>
#       <td id="T_d5821_row11_col0" class="data row11 col0" >0.750298</td>
#       <td id="T_d5821_row11_col1" class="data row11 col1" >0.562326</td>
#     </tr>
#     <tr>
#       <th id="T_d5821_level0_row12" class="row_heading level0 row12" >MaximumSequenceProbability</th>
#       <td id="T_d5821_row12_col0" class="data row12 col0" >0.504471</td>
#       <td id="T_d5821_row12_col1" class="data row12 col1" >0.558992</td>
#     </tr>
#     <tr>
#       <th id="T_d5821_level0_row13" class="row_heading level0 row13" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.0)</th>
#       <td id="T_d5821_row13_col0" class="data row13 col0" >0.574422</td>
#       <td id="T_d5821_row13_col1" class="data row13 col1" >0.547520</td>
#     </tr>
#     <tr>
#       <th id="T_d5821_level0_row14" class="row_heading level0 row14" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.9)</th>
#       <td id="T_d5821_row14_col0" class="data row14 col0" >0.718664</td>
#       <td id="T_d5821_row14_col1" class="data row14 col1" >0.544325</td>
#     </tr>
#     <tr>
#       <th id="T_d5821_level0_row15" class="row_heading level0 row15" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_d5821_row15_col0" class="data row15 col0" >0.710751</td>
#       <td id="T_d5821_row15_col1" class="data row15 col1" >0.533245</td>
#     </tr>
#     <tr>
#       <th id="T_d5821_level0_row16" class="row_heading level0 row16" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.0)</th>
#       <td id="T_d5821_row16_col0" class="data row16 col0" >0.705620</td>
#       <td id="T_d5821_row16_col1" class="data row16 col1" >0.522645</td>
#     </tr>
#     <tr>
#       <th id="T_d5821_level0_row17" class="row_heading level0 row17" >Perplexity</th>
#       <td id="T_d5821_row17_col0" class="data row17 col0" >0.005771</td>
#       <td id="T_d5821_row17_col1" class="data row17 col1" >0.255006</td>
#     </tr>
#     <tr>
#       <th id="T_d5821_level0_row18" class="row_heading level0 row18" >MeanTokenEntropy</th>
#       <td id="T_d

# %%
np.mean(man.gen_metrics[('sequence', 'Accuracy')])
# Out:
# 0.518

# %% [markdown]
# ## Mistral 7b

# %%
path = "lm-polygraph/workdir/output/qa/alpindale/Mistral-7B-v0.2-hf/sciq/2024-04-10/05-00-23/ue_manager_seed1"
man = UEManager.load(path)

metric_names = ['Accuracy', 'AlignScore']
df = {}
for key in man.metrics.keys():
    if (key[-1] == 'prr_normalized') and (key[-2] in metric_names):
        scores = df.get(key[1], [])
        scores.append(man.metrics[key])
        df[key[1]] = scores
        
df0 = pd.DataFrame(df, index=[f'SciQ, {m}, PRR' for m in metric_names])  
df0.T.sort_values(f"SciQ, {metric_names[-1]}, PRR", ascending=False).style.background_gradient(axis=0)
# Out:
# Stat calculators: [<lm_polygraph.stat_calculators.greedy_probs.GreedyProbsCalculator object at 0x7fc48b67cf40>]
# <style type="text/css">
# #T_3832a_row0_col0 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_3832a_row0_col1, #T_3832a_row15_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_3832a_row1_col0, #T_3832a_row5_col0, #T_3832a_row18_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_3832a_row1_col1, #T_3832a_row16_col0 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_3832a_row2_col0, #T_3832a_row6_col0 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_3832a_row2_col1 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_3832a_row3_col0, #T_3832a_row4_col0, #T_3832a_row8_col0 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_3832a_row3_col1, #T_3832a_row4_col1 {
#   background-color: #03456c;
#   color: #f1f1f1;
# }
# #T_3832a_row5_col1, #T_3832a_row18_col0 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# #T_3832a_row6_col1 {
#   background-color: #034973;
#   color: #f1f1f1;
# }
# #T_3832a_row7_col0, #T_3832a_row9_col0, #T_3832a_row10_col0, #T_3832a_row11_col0 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_3832a_row7_col1, #T_3832a_row8_col1 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_3832a_row9_col1 {
#   background-color: #034e7b;
#   color: #f1f1f1;
# }
# #T_3832a_row10_col1 {
#   background-color: #045585;
#   color: #f1f1f1;
# }
# #T_3832a_row11_col1 {
#   background-color: #045687;
#   color: #f1f1f1;
# }
# #T_3832a_row12_col0 {
#   background-color: #348ebf;
#   color: #f1f1f1;
# }
# #T_3832a_row12_col1 {
#   background-color: #045b8e;
#   color: #f1f1f1;
# }
# #T_3832a_row13_col0 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_3832a_row13_col1 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_3832a_row14_col0 {
#   background-color: #569dc8;
#   color: #f1f1f1;
# }
# #T_3832a_row14_col1 {
#   background-color: #046097;
#   color: #f1f1f1;
# }
# #T_3832a_row15_col1 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_3832a_row16_col1 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_3832a_row17_col0 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_3832a_row17_col1 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# </style>
# <table id="T_3832a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3832a_level0_col0" class="col_heading level0 col0" >SciQ, Accuracy, PRR</th>
#       <th id="T_3832a_level0_col1" class="col_heading level0 col1" >SciQ, AlignScore, PRR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3832a_level0_row0" class="row_heading level0 row0" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.9)</th>
#       <td id="T_3832a_row0_col0" class="data row0 col0" >-0.265819</td>
#       <td id="T_3832a_row0_col1" class="data row0 col1" >0.428868</td>
#     </tr>
#     <tr>
#       <th id="T_3832a_level0_row1" class="row_heading level0 row1" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.9)</th>
#       <td id="T_3832a_row1_col0" class="data row1 col0" >-0.331701</td>
#       <td id="T_3832a_row1_col1" class="data row1 col1" >0.414744</td>
#     </tr>
#     <tr>
#       <th id="T_3832a_level0_row2" class="row_heading level0 row2" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_3832a_row2_col0" class="data row2 col0" >-0.259495</td>
#       <td id="T_3832a_row2_col1" class="data row2 col1" >0.406263</td>
#     </tr>
#     <tr>
#       <th id="T_3832a_level0_row3" class="row_heading level0 row3" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.9)</th>
#       <td id="T_3832a_row3_col0" class="data row3 col0" >-0.326745</td>
#       <td id="T_3832a_row3_col1" class="data row3 col1" >0.393589</td>
#     </tr>
#     <tr>
#       <th id="T_3832a_level0_row4" class="row_heading level0 row4" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_3832a_row4_col0" class="data row4 col0" >-0.325507</td>
#       <td id="T_3832a_row4_col1" class="data row4 col1" >0.391920</td>
#     </tr>
#     <tr>
#       <th id="T_3832a_level0_row5" class="row_heading level0 row5" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.9)</th>
#       <td id="T_3832a_row5_col0" class="data row5 col0" >-0.331136</td>
#       <td id="T_3832a_row5_col1" class="data row5 col1" >0.390634</td>
#     </tr>
#     <tr>
#       <th id="T_3832a_level0_row6" class="row_heading level0 row6" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.0)</th>
#       <td id="T_3832a_row6_col0" class="data row6 col0" >-0.257455</td>
#       <td id="T_3832a_row6_col1" class="data row6 col1" >0.383041</td>
#     </tr>
#     <tr>
#       <th id="T_3832a_level0_row7" class="row_heading level0 row7" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_3832a_row7_col0" class="data row7 col0" >-0.321503</td>
#       <td id="T_3832a_row7_col1" class="data row7 col1" >0.374006</td>
#     </tr>
#     <tr>
#       <th id="T_3832a_level0_row8" class="row_heading level0 row8" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_3832a_row8_col0" class="data row8 col0" >-0.325209</td>
#       <td id="T_3832a_row8_col1" class="data row8 col1" >0.371871</td>
#     </tr>
#     <tr>
#       <th id="T_3832a_level0_row9" class="row_heading level0 row9" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_3832a_row9_col0" class="data row9 col0" >-0.323484</td>
#       <td id="T_3832a_row9_col1" class="data row9 col1" >0.368324</td>
#     </tr>
#     <tr>
#       <th id="T_3832a_level0_row10" class="row_heading level0 row10" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.0)</th>
#       <td id="T_3832a_row10_col0" class="data row10 col0" >-0.321003</td>
#       <td id="T_3832a_row10_col1" class="data row10 col1" >0.350302</td>
#     </tr>
#     <tr>
#       <th id="T_3832a_level0_row11" class="row_heading level0 row11" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_3832a_row11_col0" class="data row11 col0" >-0.324527</td>
#       <td id="T_3832a_row11_col1" class="data row11 col1" >0.348300</td>
#     </tr>
#     <tr>
#       <th id="T_3832a_level0_row12" class="row_heading level0 row12" >MaximumSequenceProbability</th>
#       <td id="T_3832a_row12_col0" class="data row12 col0" >0.246515</td>
#       <td id="T_3832a_row12_col1" class="data row12 col1" >0.332847</td>
#     </tr>
#     <tr>
#       <th id="T_3832a_level0_row13" class="row_heading level0 row13" >Perplexity</th>
#       <td id="T_3832a_row13_col0" class="data row13 col0" >0.201472</td>
#       <td id="T_3832a_row13_col1" class="data row13 col1" >0.311833</td>
#     </tr>
#     <tr>
#       <th id="T_3832a_level0_row14" class="row_heading level0 row14" >MeanTokenEntropy</th>
#       <td id="T_3832a_row14_col0" class="data row14 col0" >0.180955</td>
#       <td id="T_3832a_row14_col1" class="data row14 col1" >0.310559</td>
#     </tr>
#     <tr>
#       <th id="T_3832a_level0_row15" class="row_heading level0 row15" >TokenMahalanobisDistance_decoder (sum, accuracy, 1.0)</th>
#       <td id="T_3832a_row15_col0" class="data row15 col0" >0.585624</td>
#       <td id="T_3832a_row15_col1" class="data row15 col1" >-0.235857</td>
#     </tr>
#     <tr>
#       <th id="T_3832a_level0_row16" class="row_heading level0 row16" >TokenMahalanobisDistance_decoder (mean, accuracy, 1.0)</th>
#       <td id="T_3832a_row16_col0" class="data row16 col0" >0.571203</td>
#       <td id="T_3832a_row16_col1" class="data row16 col1" >-0.280940</td>
#     </tr>
#     <tr>
#       <th id="T_3832a_level0_row17" class="row_heading level0 row17" >RelativeMahalanobisDistance_decoder (sum, accuracy, 1.0)</th>
#       <td id="T_3832a_row17_col0" class="data row17 col0" >0.549240</td>
#       <td id="T_3832a_row17_col1" class="data row17 col1" >-0.293701</td>
#     </tr>
#     <tr>
#       <th id="T_3832a_level0_row18" class="row_heading level0 row18" >RelativeMahalanobisDistance_decoder (mean, accuracy, 1.0)</th>
#       <td id="T_3832a_row18_col0" class="data row18 col0" >0.536472</td>
#       <td id="T_3832a_row18_col1" class="data row18 col1" >-0.304336</td>
#     </tr>
#   </tbody>
# </table>

# %%
np.mean(man.gen_metrics[('sequence', 'Accuracy')])
# Out:
# 0.146

# %% [markdown]
# # TriviaQA

# %% [markdown]
# ## Vicuna 7b

# %%
path = "lm-polygraph/workdir/output/qa/lmsys/vicuna-7b-v1.5/['trivia_qa', 'rc.nocontext']/2024-04-09/22-25-24/ue_manager_seed1"
man = UEManager.load(path)

metric_names = ['Accuracy', 'AlignScore']
df = {}
for key in man.metrics.keys():
    if (key[-1] == 'prr_normalized') and (key[-2] in metric_names):
        scores = df.get(key[1], [])
        scores.append(man.metrics[key])
        df[key[1]] = scores
        
df0 = pd.DataFrame(df, index=[f'TriviaQA, {m}, PRR' for m in metric_names])  
df0.T.sort_values(f"TriviaQA, {metric_names[-1]}, PRR", ascending=False).style.background_gradient(axis=0)
# Out:
# Stat calculators: [<lm_polygraph.stat_calculators.greedy_probs.GreedyProbsCalculator object at 0x7fc48b67cf40>]
# <style type="text/css">
# #T_2ee00_row0_col0 {
#   background-color: #034871;
#   color: #f1f1f1;
# }
# #T_2ee00_row0_col1, #T_2ee00_row3_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_2ee00_row1_col0 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_2ee00_row1_col1, #T_2ee00_row10_col0 {
#   background-color: #046198;
#   color: #f1f1f1;
# }
# #T_2ee00_row2_col0 {
#   background-color: #023d60;
#   color: #f1f1f1;
# }
# #T_2ee00_row2_col1 {
#   background-color: #04629a;
#   color: #f1f1f1;
# }
# #T_2ee00_row3_col1 {
#   background-color: #04639b;
#   color: #f1f1f1;
# }
# #T_2ee00_row4_col0 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_2ee00_row4_col1 {
#   background-color: #0566a0;
#   color: #f1f1f1;
# }
# #T_2ee00_row5_col0 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_2ee00_row5_col1 {
#   background-color: #0a73b2;
#   color: #f1f1f1;
# }
# #T_2ee00_row6_col0 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_2ee00_row6_col1 {
#   background-color: #0c74b2;
#   color: #f1f1f1;
# }
# #T_2ee00_row7_col0 {
#   background-color: #045382;
#   color: #f1f1f1;
# }
# #T_2ee00_row7_col1 {
#   background-color: #0d75b3;
#   color: #f1f1f1;
# }
# #T_2ee00_row8_col0 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_2ee00_row8_col1 {
#   background-color: #0f76b3;
#   color: #f1f1f1;
# }
# #T_2ee00_row9_col0 {
#   background-color: #034a74;
#   color: #f1f1f1;
# }
# #T_2ee00_row9_col1 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_2ee00_row10_col1 {
#   background-color: #1278b4;
#   color: #f1f1f1;
# }
# #T_2ee00_row11_col0 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_2ee00_row11_col1 {
#   background-color: #2081b9;
#   color: #f1f1f1;
# }
# #T_2ee00_row12_col0 {
#   background-color: #187cb6;
#   color: #f1f1f1;
# }
# #T_2ee00_row12_col1 {
#   background-color: #3790c0;
#   color: #f1f1f1;
# }
# #T_2ee00_row13_col0 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_2ee00_row13_col1 {
#   background-color: #3d93c2;
#   color: #f1f1f1;
# }
# #T_2ee00_row14_col0 {
#   background-color: #05659f;
#   color: #f1f1f1;
# }
# #T_2ee00_row14_col1 {
#   background-color: #4094c3;
#   color: #f1f1f1;
# }
# #T_2ee00_row15_col0 {
#   background-color: #328dbf;
#   color: #f1f1f1;
# }
# #T_2ee00_row15_col1 {
#   background-color: #65a3cb;
#   color: #f1f1f1;
# }
# #T_2ee00_row16_col0 {
#   background-color: #529bc7;
#   color: #f1f1f1;
# }
# #T_2ee00_row16_col1 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_2ee00_row17_col0 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_2ee00_row17_col1 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_2ee00_row18_col0, #T_2ee00_row18_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_2ee00">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2ee00_level0_col0" class="col_heading level0 col0" >TriviaQA, Accuracy, PRR</th>
#       <th id="T_2ee00_level0_col1" class="col_heading level0 col1" >TriviaQA, AlignScore, PRR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2ee00_level0_row0" class="row_heading level0 row0" >MaximumSequenceProbability</th>
#       <td id="T_2ee00_row0_col0" class="data row0 col0" >0.547689</td>
#       <td id="T_2ee00_row0_col1" class="data row0 col1" >0.572455</td>
#     </tr>
#     <tr>
#       <th id="T_2ee00_level0_row1" class="row_heading level0 row1" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.9)</th>
#       <td id="T_2ee00_row1_col0" class="data row1 col0" >0.581011</td>
#       <td id="T_2ee00_row1_col1" class="data row1 col1" >0.420545</td>
#     </tr>
#     <tr>
#       <th id="T_2ee00_level0_row2" class="row_heading level0 row2" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_2ee00_row2_col0" class="data row2 col0" >0.577732</td>
#       <td id="T_2ee00_row2_col1" class="data row2 col1" >0.416744</td>
#     </tr>
#     <tr>
#       <th id="T_2ee00_level0_row3" class="row_heading level0 row3" >TokenMahalanobisDistance_decoder (sum, accuracy, 1.0)</th>
#       <td id="T_2ee00_row3_col0" class="data row3 col0" >0.595045</td>
#       <td id="T_2ee00_row3_col1" class="data row3 col1" >0.413152</td>
#     </tr>
#     <tr>
#       <th id="T_2ee00_level0_row4" class="row_heading level0 row4" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.0)</th>
#       <td id="T_2ee00_row4_col0" class="data row4 col0" >0.563798</td>
#       <td id="T_2ee00_row4_col1" class="data row4 col1" >0.398236</td>
#     </tr>
#     <tr>
#       <th id="T_2ee00_level0_row5" class="row_heading level0 row5" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.9)</th>
#       <td id="T_2ee00_row5_col0" class="data row5 col0" >0.438955</td>
#       <td id="T_2ee00_row5_col1" class="data row5 col1" >0.334290</td>
#     </tr>
#     <tr>
#       <th id="T_2ee00_level0_row6" class="row_heading level0 row6" >MeanTokenEntropy</th>
#       <td id="T_2ee00_row6_col0" class="data row6 col0" >0.127140</td>
#       <td id="T_2ee00_row6_col1" class="data row6 col1" >0.329241</td>
#     </tr>
#     <tr>
#       <th id="T_2ee00_level0_row7" class="row_heading level0 row7" >TokenMahalanobisDistance_decoder (mean, accuracy, 1.0)</th>
#       <td id="T_2ee00_row7_col0" class="data row7 col0" >0.516962</td>
#       <td id="T_2ee00_row7_col1" class="data row7 col1" >0.328341</td>
#     </tr>
#     <tr>
#       <th id="T_2ee00_level0_row8" class="row_heading level0 row8" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_2ee00_row8_col0" class="data row8 col0" >0.428726</td>
#       <td id="T_2ee00_row8_col1" class="data row8 col1" >0.324810</td>
#     </tr>
#     <tr>
#       <th id="T_2ee00_level0_row9" class="row_heading level0 row9" >RelativeMahalanobisDistance_decoder (sum, accuracy, 1.0)</th>
#       <td id="T_2ee00_row9_col0" class="data row9 col0" >0.542539</td>
#       <td id="T_2ee00_row9_col1" class="data row9 col1" >0.318825</td>
#     </tr>
#     <tr>
#       <th id="T_2ee00_level0_row10" class="row_heading level0 row10" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.9)</th>
#       <td id="T_2ee00_row10_col0" class="data row10 col0" >0.465877</td>
#       <td id="T_2ee00_row10_col1" class="data row10 col1" >0.316301</td>
#     </tr>
#     <tr>
#       <th id="T_2ee00_level0_row11" class="row_heading level0 row11" >Perplexity</th>
#       <td id="T_2ee00_row11_col0" class="data row11 col0" >0.099980</td>
#       <td id="T_2ee00_row11_col1" class="data row11 col1" >0.283894</td>
#     </tr>
#     <tr>
#       <th id="T_2ee00_level0_row12" class="row_heading level0 row12" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_2ee00_row12_col0" class="data row12 col0" >0.362114</td>
#       <td id="T_2ee00_row12_col1" class="data row12 col1" >0.231534</td>
#     </tr>
#     <tr>
#       <th id="T_2ee00_level0_row13" class="row_heading level0 row13" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.9)</th>
#       <td id="T_2ee00_row13_col0" class="data row13 col0" >0.364568</td>
#       <td id="T_2ee00_row13_col1" class="data row13 col1" >0.220635</td>
#     </tr>
#     <tr>
#       <th id="T_2ee00_level0_row14" class="row_heading level0 row14" >RelativeMahalanobisDistance_decoder (mean, accuracy, 1.0)</th>
#       <td id="T_2ee00_row14_col0" class="data row14 col0" >0.446776</td>
#       <td id="T_2ee00_row14_col1" class="data row14 col1" >0.214962</td>
#     </tr>
#     <tr>
#       <th id="T_2ee00_level0_row15" class="row_heading level0 row15" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_2ee00_row15_col0" class="data row15 col0" >0.310826</td>
#       <td id="T_2ee00_row15_col1" class="data row15 col1" >0.147379</td>
#     </tr>
#     <tr>
#       <th id="T_2ee00_level0_row16" class="row_heading level0 row16" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_2ee00_row16_col0" class="data row16 col0" >0.258959</td>
#       <td id="T_2ee00_row16_col1" class="data row16 col1" >0.107331</td>
#     </tr>
#     <tr>
#       <th id="T_2ee00_level0_row17" class="row_heading level0 row17" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_2ee00_row17_col0" class="data row17 col0" >0.037406</td>
#       <td id="T_2ee00_row17_col1" c

# %%
np.mean(man.gen_metrics[('sequence', 'Accuracy')])
# Out:
# 0.335

# %% [markdown]
# ## Vicuna 13b

# %%
path = "lm-polygraph/workdir/output/qa/lmsys/vicuna-13b-v1.5/['trivia_qa', 'rc.nocontext']/2024-04-09/22-25-24/ue_manager_seed1"
man = UEManager.load(path)

metric_names = ['Accuracy', 'AlignScore']
df = {}
for key in man.metrics.keys():
    if (key[-1] == 'prr_normalized') and (key[-2] in metric_names):
        scores = df.get(key[1], [])
        scores.append(man.metrics[key])
        df[key[1]] = scores
        
df0 = pd.DataFrame(df, index=[f'TriviaQA, {m}, PRR' for m in metric_names])  
df0.T.sort_values(f"TriviaQA, {metric_names[-1]}, PRR", ascending=False).style.background_gradient(axis=0)
# Out:
# Stat calculators: [<lm_polygraph.stat_calculators.greedy_probs.GreedyProbsCalculator object at 0x7fc48b67cf40>]
# <style type="text/css">
# #T_60209_row0_col0, #T_60209_row0_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_60209_row1_col0 {
#   background-color: #157ab5;
#   color: #f1f1f1;
# }
# #T_60209_row1_col1 {
#   background-color: #023d60;
#   color: #f1f1f1;
# }
# #T_60209_row2_col0 {
#   background-color: #0872b1;
#   color: #f1f1f1;
# }
# #T_60209_row2_col1 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_60209_row3_col0 {
#   background-color: #0a73b2;
#   color: #f1f1f1;
# }
# #T_60209_row3_col1 {
#   background-color: #187cb6;
#   color: #f1f1f1;
# }
# #T_60209_row4_col0 {
#   background-color: #0f76b3;
#   color: #f1f1f1;
# }
# #T_60209_row4_col1 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_60209_row5_col0 {
#   background-color: #04639b;
#   color: #f1f1f1;
# }
# #T_60209_row5_col1 {
#   background-color: #2987bc;
#   color: #f1f1f1;
# }
# #T_60209_row6_col0 {
#   background-color: #197db7;
#   color: #f1f1f1;
# }
# #T_60209_row6_col1 {
#   background-color: #4697c4;
#   color: #f1f1f1;
# }
# #T_60209_row7_col0 {
#   background-color: #04649e;
#   color: #f1f1f1;
# }
# #T_60209_row7_col1 {
#   background-color: #4e9ac6;
#   color: #f1f1f1;
# }
# #T_60209_row8_col0 {
#   background-color: #2c89bd;
#   color: #f1f1f1;
# }
# #T_60209_row8_col1 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_60209_row9_col0 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_60209_row9_col1 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_60209_row10_col0 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_60209_row10_col1 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_60209_row11_col0, #T_60209_row15_col0 {
#   background-color: #348ebf;
#   color: #f1f1f1;
# }
# #T_60209_row11_col1 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_60209_row12_col0 {
#   background-color: #529bc7;
#   color: #f1f1f1;
# }
# #T_60209_row12_col1 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# #T_60209_row13_col0 {
#   background-color: #308cbe;
#   color: #f1f1f1;
# }
# #T_60209_row13_col1, #T_60209_row14_col1 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_60209_row14_col0 {
#   background-color: #2383ba;
#   color: #f1f1f1;
# }
# #T_60209_row15_col1, #T_60209_row17_col0 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_60209_row16_col0 {
#   background-color: #4094c3;
#   color: #f1f1f1;
# }
# #T_60209_row16_col1 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_60209_row17_col1 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_60209_row18_col0, #T_60209_row18_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_60209">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_60209_level0_col0" class="col_heading level0 col0" >TriviaQA, Accuracy, PRR</th>
#       <th id="T_60209_level0_col1" class="col_heading level0 col1" >TriviaQA, AlignScore, PRR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_60209_level0_row0" class="row_heading level0 row0" >MaximumSequenceProbability</th>
#       <td id="T_60209_row0_col0" class="data row0 col0" >0.649271</td>
#       <td id="T_60209_row0_col1" class="data row0 col1" >0.596263</td>
#     </tr>
#     <tr>
#       <th id="T_60209_level0_row1" class="row_heading level0 row1" >MeanTokenEntropy</th>
#       <td id="T_60209_row1_col0" class="data row1 col0" >0.473291</td>
#       <td id="T_60209_row1_col1" class="data row1 col1" >0.581673</td>
#     </tr>
#     <tr>
#       <th id="T_60209_level0_row2" class="row_heading level0 row2" >Perplexity</th>
#       <td id="T_60209_row2_col0" class="data row2 col0" >0.493253</td>
#       <td id="T_60209_row2_col1" class="data row2 col1" >0.548530</td>
#     </tr>
#     <tr>
#       <th id="T_60209_level0_row3" class="row_heading level0 row3" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.9)</th>
#       <td id="T_60209_row3_col0" class="data row3 col0" >0.490199</td>
#       <td id="T_60209_row3_col1" class="data row3 col1" >0.410863</td>
#     </tr>
#     <tr>
#       <th id="T_60209_level0_row4" class="row_heading level0 row4" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_60209_row4_col0" class="data row4 col0" >0.483249</td>
#       <td id="T_60209_row4_col1" class="data row4 col1" >0.400115</td>
#     </tr>
#     <tr>
#       <th id="T_60209_level0_row5" class="row_heading level0 row5" >TokenMahalanobisDistance_decoder (mean, accuracy, 1.0)</th>
#       <td id="T_60209_row5_col0" class="data row5 col0" >0.541686</td>
#       <td id="T_60209_row5_col1" class="data row5 col1" >0.382376</td>
#     </tr>
#     <tr>
#       <th id="T_60209_level0_row6" class="row_heading level0 row6" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.9)</th>
#       <td id="T_60209_row6_col0" class="data row6 col0" >0.466970</td>
#       <td id="T_60209_row6_col1" class="data row6 col1" >0.341137</td>
#     </tr>
#     <tr>
#       <th id="T_60209_level0_row7" class="row_heading level0 row7" >RelativeMahalanobisDistance_decoder (sum, accuracy, 1.0)</th>
#       <td id="T_60209_row7_col0" class="data row7 col0" >0.538213</td>
#       <td id="T_60209_row7_col1" class="data row7 col1" >0.331156</td>
#     </tr>
#     <tr>
#       <th id="T_60209_level0_row8" class="row_heading level0 row8" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.9)</th>
#       <td id="T_60209_row8_col0" class="data row8 col0" >0.438831</td>
#       <td id="T_60209_row8_col1" class="data row8 col1" >0.329843</td>
#     </tr>
#     <tr>
#       <th id="T_60209_level0_row9" class="row_heading level0 row9" >RelativeMahalanobisDistance_decoder (mean, accuracy, 1.0)</th>
#       <td id="T_60209_row9_col0" class="data row9 col0" >0.509496</td>
#       <td id="T_60209_row9_col1" class="data row9 col1" >0.313983</td>
#     </tr>
#     <tr>
#       <th id="T_60209_level0_row10" class="row_heading level0 row10" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_60209_row10_col0" class="data row10 col0" >0.423683</td>
#       <td id="T_60209_row10_col1" class="data row10 col1" >0.312012</td>
#     </tr>
#     <tr>
#       <th id="T_60209_level0_row11" class="row_heading level0 row11" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_60209_row11_col0" class="data row11 col0" >0.425100</td>
#       <td id="T_60209_row11_col1" class="data row11 col1" >0.306824</td>
#     </tr>
#     <tr>
#       <th id="T_60209_level0_row12" class="row_heading level0 row12" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_60209_row12_col0" class="data row12 col0" >0.388938</td>
#       <td id="T_60209_row12_col1" class="data row12 col1" >0.301042</td>
#     </tr>
#     <tr>
#       <th id="T_60209_level0_row13" class="row_heading level0 row13" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.9)</th>
#       <td id="T_60209_row13_col0" class="data row13 col0" >0.430133</td>
#       <td id="T_60209_row13_col1" class="data row13 col1" >0.262133</td>
#     </tr>
#     <tr>
#       <th id="T_60209_level0_row14" class="row_heading level0 row14" >TokenMahalanobisDistance_decoder (sum, accuracy, 1.0)</th>
#       <td id="T_60209_row14_col0" class="data row14 col0" >0.450933</td>
#       <td id="T_60209_row14_col1" class="data row14 col1" >0.260927</td>
#     </tr>
#     <tr>
#       <th id="T_60209_level0_row15" class="row_heading level0 row15" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_60209_row15_col0" class="data row15 col0" >0.424892</td>
#       <td id="T_60209_row15_col1" class="data row15 col1" >0.254378</td>
#     </tr>
#     <tr>
#       <th id="T_60209_level0_row16" class="row_heading level0 row16" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.0)</th>
#       <td id="T_60209_row16_col0" class="data row16 col0" >0.409694</td>
#       <td id="T_60209_row16_col1" class="data row16 col1" >0.234146</td>
#     </tr>
#     <tr>
#       <th id="T_60209_level0_row17" class="row_heading level0 row17" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_60209_row17_col0" class="data row17 col0" >0.318184</td>
#       <td id="T_60209_row17_col1" class="data row17 col1" >0.156556</td>
#     </tr>
#     <tr>
#       <th id="T_60209_level0_row18" class="

# %%
np.mean(man.gen_metrics[('sequence', 'Accuracy')])
# Out:
# 0.528

# %% [markdown]
# ## Mistral 7b

# %%
path = "lm-polygraph/workdir/output/qa/alpindale/Mistral-7B-v0.2-hf/['trivia_qa', 'rc.nocontext']/2024-04-10/05-00-05/ue_manager_seed1"
man = UEManager.load(path)

metric_names = ['Accuracy', 'AlignScore']
df = {}
for key in man.metrics.keys():
    if (key[-1] == 'prr_normalized') and (key[-2] in metric_names):
        scores = df.get(key[1], [])
        scores.append(man.metrics[key])
        df[key[1]] = scores
        
df0 = pd.DataFrame(df, index=[f'TriviaQA, {m}, PRR' for m in metric_names])  
df0.T.sort_values(f"TriviaQA, {metric_names[-1]}, PRR", ascending=False).style.background_gradient(axis=0)
# Out:
# Stat calculators: [<lm_polygraph.stat_calculators.greedy_probs.GreedyProbsCalculator object at 0x7fc48b67cf40>]
# <style type="text/css">
# #T_76497_row0_col0 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_76497_row0_col1, #T_76497_row15_col0, #T_76497_row16_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_76497_row1_col0, #T_76497_row2_col0, #T_76497_row17_col1, #T_76497_row18_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_76497_row1_col1, #T_76497_row2_col1 {
#   background-color: #03456c;
#   color: #f1f1f1;
# }
# #T_76497_row3_col0, #T_76497_row4_col0 {
#   background-color: #04629a;
#   color: #f1f1f1;
# }
# #T_76497_row3_col1, #T_76497_row4_col1 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_76497_row5_col0, #T_76497_row6_col0 {
#   background-color: #034b76;
#   color: #f1f1f1;
# }
# #T_76497_row5_col1, #T_76497_row6_col1 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_76497_row7_col0, #T_76497_row8_col0 {
#   background-color: #023b5d;
#   color: #f1f1f1;
# }
# #T_76497_row7_col1, #T_76497_row8_col1 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_76497_row9_col0, #T_76497_row10_col0 {
#   background-color: #046198;
#   color: #f1f1f1;
# }
# #T_76497_row9_col1, #T_76497_row10_col1 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_76497_row11_col0, #T_76497_row12_col0 {
#   background-color: #045e94;
#   color: #f1f1f1;
# }
# #T_76497_row11_col1, #T_76497_row12_col1 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_76497_row13_col0, #T_76497_row14_col0 {
#   background-color: #034871;
#   color: #f1f1f1;
# }
# #T_76497_row13_col1, #T_76497_row14_col1 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_76497_row15_col1, #T_76497_row16_col1 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_76497_row17_col0, #T_76497_row18_col0 {
#   background-color: #045e93;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_76497">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_76497_level0_col0" class="col_heading level0 col0" >TriviaQA, Accuracy, PRR</th>
#       <th id="T_76497_level0_col1" class="col_heading level0 col1" >TriviaQA, AlignScore, PRR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76497_level0_row0" class="row_heading level0 row0" >MeanTokenEntropy</th>
#       <td id="T_76497_row0_col0" class="data row0 col0" >0.088757</td>
#       <td id="T_76497_row0_col1" class="data row0 col1" >0.269215</td>
#     </tr>
#     <tr>
#       <th id="T_76497_level0_row1" class="row_heading level0 row1" >MaximumSequenceProbability</th>
#       <td id="T_76497_row1_col0" class="data row1 col0" >0.069616</td>
#       <td id="T_76497_row1_col1" class="data row1 col1" >0.258446</td>
#     </tr>
#     <tr>
#       <th id="T_76497_level0_row2" class="row_heading level0 row2" >Perplexity</th>
#       <td id="T_76497_row2_col0" class="data row2 col0" >0.069616</td>
#       <td id="T_76497_row2_col1" class="data row2 col1" >0.258446</td>
#     </tr>
#     <tr>
#       <th id="T_76497_level0_row3" class="row_heading level0 row3" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.9)</th>
#       <td id="T_76497_row3_col0" class="data row3 col0" >0.344637</td>
#       <td id="T_76497_row3_col1" class="data row3 col1" >0.138475</td>
#     </tr>
#     <tr>
#       <th id="T_76497_level0_row4" class="row_heading level0 row4" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.9)</th>
#       <td id="T_76497_row4_col0" class="data row4 col0" >0.344637</td>
#       <td id="T_76497_row4_col1" class="data row4 col1" >0.138475</td>
#     </tr>
#     <tr>
#       <th id="T_76497_level0_row5" class="row_heading level0 row5" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_76497_row5_col0" class="data row5 col0" >0.377890</td>
#       <td id="T_76497_row5_col1" class="data row5 col1" >0.130340</td>
#     </tr>
#     <tr>
#       <th id="T_76497_level0_row6" class="row_heading level0 row6" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_76497_row6_col0" class="data row6 col0" >0.377890</td>
#       <td id="T_76497_row6_col1" class="data row6 col1" >0.130340</td>
#     </tr>
#     <tr>
#       <th id="T_76497_level0_row7" class="row_heading level0 row7" >TokenMahalanobisDistance_decoder (mean, accuracy, 1.0)</th>
#       <td id="T_76497_row7_col0" class="data row7 col0" >0.398288</td>
#       <td id="T_76497_row7_col1" class="data row7 col1" >0.118540</td>
#     </tr>
#     <tr>
#       <th id="T_76497_level0_row8" class="row_heading level0 row8" >TokenMahalanobisDistance_decoder (sum, accuracy, 1.0)</th>
#       <td id="T_76497_row8_col0" class="data row8 col0" >0.398288</td>
#       <td id="T_76497_row8_col1" class="data row8 col1" >0.118540</td>
#     </tr>
#     <tr>
#       <th id="T_76497_level0_row9" class="row_heading level0 row9" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.9)</th>
#       <td id="T_76497_row9_col0" class="data row9 col0" >0.347659</td>
#       <td id="T_76497_row9_col1" class="data row9 col1" >0.115769</td>
#     </tr>
#     <tr>
#       <th id="T_76497_level0_row10" class="row_heading level0 row10" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.9)</th>
#       <td id="T_76497_row10_col0" class="data row10 col0" >0.347659</td>
#       <td id="T_76497_row10_col1" class="data row10 col1" >0.115769</td>
#     </tr>
#     <tr>
#       <th id="T_76497_level0_row11" class="row_heading level0 row11" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_76497_row11_col0" class="data row11 col0" >0.352210</td>
#       <td id="T_76497_row11_col1" class="data row11 col1" >0.097694</td>
#     </tr>
#     <tr>
#       <th id="T_76497_level0_row12" class="row_heading level0 row12" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.0)</th>
#       <td id="T_76497_row12_col0" class="data row12 col0" >0.352210</td>
#       <td id="T_76497_row12_col1" class="data row12 col1" >0.097694</td>
#     </tr>
#     <tr>
#       <th id="T_76497_level0_row13" class="row_heading level0 row13" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_76497_row13_col0" class="data row13 col0" >0.382631</td>
#       <td id="T_76497_row13_col1" class="data row13 col1" >0.097035</td>
#     </tr>
#     <tr>
#       <th id="T_76497_level0_row14" class="row_heading level0 row14" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_76497_row14_col0" class="data row14 col0" >0.382631</td>
#       <td id="T_76497_row14_col1" class="data row14 col1" >0.097035</td>
#     </tr>
#     <tr>
#       <th id="T_76497_level0_row15" class="row_heading level0 row15" >RelativeMahalanobisDistance_decoder (mean, accuracy, 1.0)</th>
#       <td id="T_76497_row15_col0" class="data row15 col0" >0.402281</td>
#       <td id="T_76497_row15_col1" class="data row15 col1" >0.089298</td>
#     </tr>
#     <tr>
#       <th id="T_76497_level0_row16" class="row_heading level0 row16" >RelativeMahalanobisDistance_decoder (sum, accuracy, 1.0)</th>
#       <td id="T_76497_row16_col0" class="data row16 col0" >0.402281</td>
#       <td id="T_76497_row16_col1" class="data row16 col1" >0.089298</td>
#     </tr>
#     <tr>
#       <th id="T_76497_level0_row17" class="row_heading level0 row17" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.0)</th>
#       <td id="T_76497_row17_col0" class="data row17 col0" >0.353725</td>
#       <td id="T_76497_row17_col1" class="data row17 col1" >0.056743</td>
#     </tr>
#     <tr>
#       <th id="T_76497_level0_row18" class="row_heading level0 row18" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_76497_row18_col0" class="data row18 col0" >0.353725</td>
#       <td id="T_76497_row18_col1" class="data row18 col1" >0.056743</td>
#     </tr>
#   </tbody>
# </table>

# %%
np.mean(man.gen_metrics[('sequence', 'Accuracy')])
# Out:
# 0.558

# %% [markdown]
# # MMLU

# %% [markdown]
# ## Vicuna 7b

# %%
path = "lm-polygraph/workdir/output/qa/lmsys/vicuna-7b-v1.5/['cais/mmlu', 'all']/2024-04-09/22-25-26/ue_manager_seed1"
man = UEManager.load(path)

metric_names = ['Accuracy']
df = {}
for key in man.metrics.keys():
    if (key[-1] == 'prr_normalized') and (key[-2] in metric_names):
        scores = df.get(key[1], [])
        scores.append(man.metrics[key])
        df[key[1]] = scores
        
df0 = pd.DataFrame(df, index=[f'MMLU, {m}, PRR' for m in metric_names])  
df0.T.sort_values(f"MMLU, {metric_names[-1]}, PRR", ascending=False).style.background_gradient(axis=0)
# Out:
# Stat calculators: [<lm_polygraph.stat_calculators.greedy_probs.GreedyProbsCalculator object at 0x7fc48b67cf40>]
# <style type="text/css">
# #T_96a10_row0_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_96a10_row1_col0, #T_96a10_row2_col0 {
#   background-color: #034f7d;
#   color: #f1f1f1;
# }
# #T_96a10_row3_col0, #T_96a10_row4_col0 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_96a10_row5_col0, #T_96a10_row6_col0 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_96a10_row7_col0, #T_96a10_row8_col0 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_96a10_row9_col0, #T_96a10_row10_col0 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_96a10_row11_col0, #T_96a10_row12_col0 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_96a10_row13_col0, #T_96a10_row14_col0 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_96a10_row15_col0, #T_96a10_row16_col0 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_96a10_row17_col0, #T_96a10_row18_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_96a10">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_96a10_level0_col0" class="col_heading level0 col0" >MMLU, Accuracy, PRR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_96a10_level0_row0" class="row_heading level0 row0" >MeanTokenEntropy</th>
#       <td id="T_96a10_row0_col0" class="data row0 col0" >0.474275</td>
#     </tr>
#     <tr>
#       <th id="T_96a10_level0_row1" class="row_heading level0 row1" >MaximumSequenceProbability</th>
#       <td id="T_96a10_row1_col0" class="data row1 col0" >0.449569</td>
#     </tr>
#     <tr>
#       <th id="T_96a10_level0_row2" class="row_heading level0 row2" >Perplexity</th>
#       <td id="T_96a10_row2_col0" class="data row2 col0" >0.449569</td>
#     </tr>
#     <tr>
#       <th id="T_96a10_level0_row3" class="row_heading level0 row3" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_96a10_row3_col0" class="data row3 col0" >0.250325</td>
#     </tr>
#     <tr>
#       <th id="T_96a10_level0_row4" class="row_heading level0 row4" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_96a10_row4_col0" class="data row4 col0" >0.250325</td>
#     </tr>
#     <tr>
#       <th id="T_96a10_level0_row5" class="row_heading level0 row5" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_96a10_row5_col0" class="data row5 col0" >0.248022</td>
#     </tr>
#     <tr>
#       <th id="T_96a10_level0_row6" class="row_heading level0 row6" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_96a10_row6_col0" class="data row6 col0" >0.248022</td>
#     </tr>
#     <tr>
#       <th id="T_96a10_level0_row7" class="row_heading level0 row7" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.0)</th>
#       <td id="T_96a10_row7_col0" class="data row7 col0" >0.220600</td>
#     </tr>
#     <tr>
#       <th id="T_96a10_level0_row8" class="row_heading level0 row8" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_96a10_row8_col0" class="data row8 col0" >0.220600</td>
#     </tr>
#     <tr>
#       <th id="T_96a10_level0_row9" class="row_heading level0 row9" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_96a10_row9_col0" class="data row9 col0" >0.219658</td>
#     </tr>
#     <tr>
#       <th id="T_96a10_level0_row10" class="row_heading level0 row10" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.0)</th>
#       <td id="T_96a10_row10_col0" class="data row10 col0" >0.219658</td>
#     </tr>
#     <tr>
#       <th id="T_96a10_level0_row11" class="row_heading level0 row11" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.9)</th>
#       <td id="T_96a10_row11_col0" class="data row11 col0" >0.201249</td>
#     </tr>
#     <tr>
#       <th id="T_96a10_level0_row12" class="row_heading level0 row12" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.9)</th>
#       <td id="T_96a10_row12_col0" class="data row12 col0" >0.201249</td>
#     </tr>
#     <tr>
#       <th id="T_96a10_level0_row13" class="row_heading level0 row13" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.9)</th>
#       <td id="T_96a10_row13_col0" class="data row13 col0" >0.199409</td>
#     </tr>
#     <tr>
#       <th id="T_96a10_level0_row14" class="row_heading level0 row14" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.9)</th>
#       <td id="T_96a10_row14_col0" class="data row14 col0" >0.199409</td>
#     </tr>
#     <tr>
#       <th id="T_96a10_level0_row15" class="row_heading level0 row15" >TokenMahalanobisDistance_decoder (sum, accuracy, 1.0)</th>
#       <td id="T_96a10_row15_col0" class="data row15 col0" >0.196722</td>
#     </tr>
#     <tr>
#       <th id="T_96a10_level0_row16" class="row_heading level0 row16" >TokenMahalanobisDistance_decoder (mean, accuracy, 1.0)</th>
#       <td id="T_96a10_row16_col0" class="data row16 col0" >0.196722</td>
#     </tr>
#     <tr>
#       <th id="T_96a10_level0_row17" class="row_heading level0 row17" >RelativeMahalanobisDistance_decoder (mean, accuracy, 1.0)</th>
#       <td id="T_96a10_row17_col0" class="data row17 col0" >0.194943</td>
#     </tr>
#     <tr>
#       <th id="T_96a10_level0_row18" class="row_heading level0 row18" >RelativeMahalanobisDistance_decoder (sum, accuracy, 1.0)</th>
#       <td id="T_96a10_row18_col0" class="data row18 col0" >0.194943</td>
#     </tr>
#   </tbody>
# </table>

# %%
np.mean(man.gen_metrics[('sequence', 'Accuracy')])
# Out:
# 0.403

# %% [markdown]
# ## Vicuna 13b

# %%
path = "lm-polygraph/workdir/output/qa/lmsys/vicuna-13b-v1.5/['cais/mmlu', 'all']/2024-04-09/22-25-26/ue_manager_seed1"
man = UEManager.load(path)

metric_names = ['Accuracy']
df = {}
for key in man.metrics.keys():
    if (key[-1] == 'prr_normalized') and (key[-2] in metric_names):
        scores = df.get(key[1], [])
        scores.append(man.metrics[key])
        df[key[1]] = scores
        
df0 = pd.DataFrame(df, index=[f'MMLU, {m}, PRR' for m in metric_names])  
df0.T.sort_values(f"MMLU, {metric_names[-1]}, PRR", ascending=False).style.background_gradient(axis=0)
# Out:
# Stat calculators: [<lm_polygraph.stat_calculators.greedy_probs.GreedyProbsCalculator object at 0x7fc48b67cf40>]
# <style type="text/css">
# #T_6548c_row0_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_6548c_row1_col0, #T_6548c_row2_col0 {
#   background-color: #023d60;
#   color: #f1f1f1;
# }
# #T_6548c_row3_col0, #T_6548c_row4_col0 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_6548c_row5_col0, #T_6548c_row6_col0 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_6548c_row7_col0, #T_6548c_row8_col0, #T_6548c_row9_col0, #T_6548c_row10_col0 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_6548c_row11_col0, #T_6548c_row12_col0, #T_6548c_row13_col0, #T_6548c_row14_col0 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_6548c_row15_col0, #T_6548c_row16_col0, #T_6548c_row17_col0, #T_6548c_row18_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_6548c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6548c_level0_col0" class="col_heading level0 col0" >MMLU, Accuracy, PRR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6548c_level0_row0" class="row_heading level0 row0" >MeanTokenEntropy</th>
#       <td id="T_6548c_row0_col0" class="data row0 col0" >0.653613</td>
#     </tr>
#     <tr>
#       <th id="T_6548c_level0_row1" class="row_heading level0 row1" >MaximumSequenceProbability</th>
#       <td id="T_6548c_row1_col0" class="data row1 col0" >0.642444</td>
#     </tr>
#     <tr>
#       <th id="T_6548c_level0_row2" class="row_heading level0 row2" >Perplexity</th>
#       <td id="T_6548c_row2_col0" class="data row2 col0" >0.642444</td>
#     </tr>
#     <tr>
#       <th id="T_6548c_level0_row3" class="row_heading level0 row3" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_6548c_row3_col0" class="data row3 col0" >0.160387</td>
#     </tr>
#     <tr>
#       <th id="T_6548c_level0_row4" class="row_heading level0 row4" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.0)</th>
#       <td id="T_6548c_row4_col0" class="data row4 col0" >0.160387</td>
#     </tr>
#     <tr>
#       <th id="T_6548c_level0_row5" class="row_heading level0 row5" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.0)</th>
#       <td id="T_6548c_row5_col0" class="data row5 col0" >0.158379</td>
#     </tr>
#     <tr>
#       <th id="T_6548c_level0_row6" class="row_heading level0 row6" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_6548c_row6_col0" class="data row6 col0" >0.158379</td>
#     </tr>
#     <tr>
#       <th id="T_6548c_level0_row7" class="row_heading level0 row7" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_6548c_row7_col0" class="data row7 col0" >0.127214</td>
#     </tr>
#     <tr>
#       <th id="T_6548c_level0_row8" class="row_heading level0 row8" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_6548c_row8_col0" class="data row8 col0" >0.127214</td>
#     </tr>
#     <tr>
#       <th id="T_6548c_level0_row9" class="row_heading level0 row9" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_6548c_row9_col0" class="data row9 col0" >0.127011</td>
#     </tr>
#     <tr>
#       <th id="T_6548c_level0_row10" class="row_heading level0 row10" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_6548c_row10_col0" class="data row10 col0" >0.127011</td>
#     </tr>
#     <tr>
#       <th id="T_6548c_level0_row11" class="row_heading level0 row11" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.9)</th>
#       <td id="T_6548c_row11_col0" class="data row11 col0" >0.106704</td>
#     </tr>
#     <tr>
#       <th id="T_6548c_level0_row12" class="row_heading level0 row12" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.9)</th>
#       <td id="T_6548c_row12_col0" class="data row12 col0" >0.106704</td>
#     </tr>
#     <tr>
#       <th id="T_6548c_level0_row13" class="row_heading level0 row13" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.9)</th>
#       <td id="T_6548c_row13_col0" class="data row13 col0" >0.106357</td>
#     </tr>
#     <tr>
#       <th id="T_6548c_level0_row14" class="row_heading level0 row14" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.9)</th>
#       <td id="T_6548c_row14_col0" class="data row14 col0" >0.106357</td>
#     </tr>
#     <tr>
#       <th id="T_6548c_level0_row15" class="row_heading level0 row15" >TokenMahalanobisDistance_decoder (sum, accuracy, 1.0)</th>
#       <td id="T_6548c_row15_col0" class="data row15 col0" >0.094193</td>
#     </tr>
#     <tr>
#       <th id="T_6548c_level0_row16" class="row_heading level0 row16" >TokenMahalanobisDistance_decoder (mean, accuracy, 1.0)</th>
#       <td id="T_6548c_row16_col0" class="data row16 col0" >0.094193</td>
#     </tr>
#     <tr>
#       <th id="T_6548c_level0_row17" class="row_heading level0 row17" >RelativeMahalanobisDistance_decoder (mean, accuracy, 1.0)</th>
#       <td id="T_6548c_row17_col0" class="data row17 col0" >0.093959</td>
#     </tr>
#     <tr>
#       <th id="T_6548c_level0_row18" class="row_heading level0 row18" >RelativeMahalanobisDistance_decoder (sum, accuracy, 1.0)</th>
#       <td id="T_6548c_row18_col0" class="data row18 col0" >0.093959</td>
#     </tr>
#   </tbody>
# </table>

# %%
np.mean(man.gen_metrics[('sequence', 'Accuracy')])
# Out:
# 0.4865

# %% [markdown]
# ## Mistral 7b

# %%
path = "lm-polygraph/workdir/output/qa/alpindale/Mistral-7B-v0.2-hf/['cais/mmlu', 'all']/2024-04-10/05-00-23/ue_manager_seed1"
man = UEManager.load(path)

metric_names = ['Accuracy']
df = {}
for key in man.metrics.keys():
    if (key[-1] == 'prr_normalized') and (key[-2] in metric_names):
        scores = df.get(key[1], [])
        scores.append(man.metrics[key])
        df[key[1]] = scores
        
df0 = pd.DataFrame(df, index=[f'MMLU, {m}, PRR' for m in metric_names])  
df0.T.sort_values(f"MMLU, {metric_names[-1]}, PRR", ascending=False).style.background_gradient(axis=0)
# Out:
# Stat calculators: [<lm_polygraph.stat_calculators.greedy_probs.GreedyProbsCalculator object at 0x7fc48b67cf40>]
# <style type="text/css">
# #T_1539c_row0_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_1539c_row1_col0, #T_1539c_row2_col0 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_1539c_row3_col0, #T_1539c_row4_col0 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_1539c_row5_col0, #T_1539c_row6_col0 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_1539c_row7_col0, #T_1539c_row8_col0, #T_1539c_row9_col0, #T_1539c_row10_col0, #T_1539c_row11_col0, #T_1539c_row12_col0, #T_1539c_row13_col0, #T_1539c_row14_col0 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_1539c_row15_col0, #T_1539c_row16_col0, #T_1539c_row17_col0, #T_1539c_row18_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_1539c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1539c_level0_col0" class="col_heading level0 col0" >MMLU, Accuracy, PRR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1539c_level0_row0" class="row_heading level0 row0" >MeanTokenEntropy</th>
#       <td id="T_1539c_row0_col0" class="data row0 col0" >0.695688</td>
#     </tr>
#     <tr>
#       <th id="T_1539c_level0_row1" class="row_heading level0 row1" >MaximumSequenceProbability</th>
#       <td id="T_1539c_row1_col0" class="data row1 col0" >0.678909</td>
#     </tr>
#     <tr>
#       <th id="T_1539c_level0_row2" class="row_heading level0 row2" >Perplexity</th>
#       <td id="T_1539c_row2_col0" class="data row2 col0" >0.678909</td>
#     </tr>
#     <tr>
#       <th id="T_1539c_level0_row3" class="row_heading level0 row3" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_1539c_row3_col0" class="data row3 col0" >0.151506</td>
#     </tr>
#     <tr>
#       <th id="T_1539c_level0_row4" class="row_heading level0 row4" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_1539c_row4_col0" class="data row4 col0" >0.151506</td>
#     </tr>
#     <tr>
#       <th id="T_1539c_level0_row5" class="row_heading level0 row5" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_1539c_row5_col0" class="data row5 col0" >0.150787</td>
#     </tr>
#     <tr>
#       <th id="T_1539c_level0_row6" class="row_heading level0 row6" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_1539c_row6_col0" class="data row6 col0" >0.150787</td>
#     </tr>
#     <tr>
#       <th id="T_1539c_level0_row7" class="row_heading level0 row7" >TokenMahalanobisDistance_decoder (mean, accuracy, 1.0)</th>
#       <td id="T_1539c_row7_col0" class="data row7 col0" >0.111301</td>
#     </tr>
#     <tr>
#       <th id="T_1539c_level0_row8" class="row_heading level0 row8" >TokenMahalanobisDistance_decoder (sum, accuracy, 1.0)</th>
#       <td id="T_1539c_row8_col0" class="data row8 col0" >0.111301</td>
#     </tr>
#     <tr>
#       <th id="T_1539c_level0_row9" class="row_heading level0 row9" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.9)</th>
#       <td id="T_1539c_row9_col0" class="data row9 col0" >0.111301</td>
#     </tr>
#     <tr>
#       <th id="T_1539c_level0_row10" class="row_heading level0 row10" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.9)</th>
#       <td id="T_1539c_row10_col0" class="data row10 col0" >0.111301</td>
#     </tr>
#     <tr>
#       <th id="T_1539c_level0_row11" class="row_heading level0 row11" >RelativeMahalanobisDistance_decoder (mean, accuracy, 1.0)</th>
#       <td id="T_1539c_row11_col0" class="data row11 col0" >0.110145</td>
#     </tr>
#     <tr>
#       <th id="T_1539c_level0_row12" class="row_heading level0 row12" >RelativeMahalanobisDistance_decoder (sum, accuracy, 1.0)</th>
#       <td id="T_1539c_row12_col0" class="data row12 col0" >0.110145</td>
#     </tr>
#     <tr>
#       <th id="T_1539c_level0_row13" class="row_heading level0 row13" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.9)</th>
#       <td id="T_1539c_row13_col0" class="data row13 col0" >0.110145</td>
#     </tr>
#     <tr>
#       <th id="T_1539c_level0_row14" class="row_heading level0 row14" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.9)</th>
#       <td id="T_1539c_row14_col0" class="data row14 col0" >0.110145</td>
#     </tr>
#     <tr>
#       <th id="T_1539c_level0_row15" class="row_heading level0 row15" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_1539c_row15_col0" class="data row15 col0" >0.098148</td>
#     </tr>
#     <tr>
#       <th id="T_1539c_level0_row16" class="row_heading level0 row16" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.0)</th>
#       <td id="T_1539c_row16_col0" class="data row16 col0" >0.098148</td>
#     </tr>
#     <tr>
#       <th id="T_1539c_level0_row17" class="row_heading level0 row17" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.0)</th>
#       <td id="T_1539c_row17_col0" class="data row17 col0" >0.097757</td>
#     </tr>
#     <tr>
#       <th id="T_1539c_level0_row18" class="row_heading level0 row18" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_1539c_row18_col0" class="data row18 col0" >0.097757</td>
#     </tr>
#   </tbody>
# </table>

# %%
np.mean(man.gen_metrics[('sequence', 'Accuracy')])
# Out:
# 0.5575

# %% [markdown]
# # GSM8k

# %% [markdown]
# ## Vicuna 7b

# %%
path = "lm-polygraph/workdir/output/qa/lmsys/vicuna-7b-v1.5/['gsm8k', 'main']/2024-04-09/23-14-31/ue_manager_seed1"
man = UEManager.load(path)

metric_names = ['Accuracy']
df = {}
for key in man.metrics.keys():
    if (key[-1] == 'prr_normalized') and (key[-2] in metric_names):
        scores = df.get(key[1], [])
        scores.append(man.metrics[key])
        df[key[1]] = scores
        
df0 = pd.DataFrame(df, index=[f'GSM8k, {m}, PRR' for m in metric_names])  
df0.T.sort_values(f"GSM8k, {metric_names[-1]}, PRR", ascending=False).style.background_gradient(axis=0)
# Out:
# Stat calculators: [<lm_polygraph.stat_calculators.greedy_probs.GreedyProbsCalculator object at 0x7fc48b67cf40>]
# <style type="text/css">
# #T_5e22c_row0_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_5e22c_row1_col0 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_5e22c_row2_col0 {
#   background-color: #034f7d;
#   color: #f1f1f1;
# }
# #T_5e22c_row3_col0 {
#   background-color: #03517e;
#   color: #f1f1f1;
# }
# #T_5e22c_row4_col0 {
#   background-color: #045585;
#   color: #f1f1f1;
# }
# #T_5e22c_row5_col0 {
#   background-color: #045e94;
#   color: #f1f1f1;
# }
# #T_5e22c_row6_col0 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T_5e22c_row7_col0 {
#   background-color: #1278b4;
#   color: #f1f1f1;
# }
# #T_5e22c_row8_col0 {
#   background-color: #2383ba;
#   color: #f1f1f1;
# }
# #T_5e22c_row9_col0 {
#   background-color: #4094c3;
#   color: #f1f1f1;
# }
# #T_5e22c_row10_col0 {
#   background-color: #4697c4;
#   color: #f1f1f1;
# }
# #T_5e22c_row11_col0 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_5e22c_row12_col0 {
#   background-color: #76aad0;
#   color: #f1f1f1;
# }
# #T_5e22c_row13_col0 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_5e22c_row14_col0 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_5e22c_row15_col0 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_5e22c_row16_col0 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_5e22c_row17_col0 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_5e22c_row18_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_5e22c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5e22c_level0_col0" class="col_heading level0 col0" >GSM8k, Accuracy, PRR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e22c_level0_row0" class="row_heading level0 row0" >RelativeMahalanobisDistance_decoder (sum, accuracy, 1.0)</th>
#       <td id="T_5e22c_row0_col0" class="data row0 col0" >0.457930</td>
#     </tr>
#     <tr>
#       <th id="T_5e22c_level0_row1" class="row_heading level0 row1" >TokenMahalanobisDistance_decoder (mean, accuracy, 1.0)</th>
#       <td id="T_5e22c_row1_col0" class="data row1 col0" >0.448746</td>
#     </tr>
#     <tr>
#       <th id="T_5e22c_level0_row2" class="row_heading level0 row2" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.9)</th>
#       <td id="T_5e22c_row2_col0" class="data row2 col0" >0.431895</td>
#     </tr>
#     <tr>
#       <th id="T_5e22c_level0_row3" class="row_heading level0 row3" >RelativeMahalanobisDistance_decoder (mean, accuracy, 1.0)</th>
#       <td id="T_5e22c_row3_col0" class="data row3 col0" >0.430294</td>
#     </tr>
#     <tr>
#       <th id="T_5e22c_level0_row4" class="row_heading level0 row4" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_5e22c_row4_col0" class="data row4 col0" >0.425684</td>
#     </tr>
#     <tr>
#       <th id="T_5e22c_level0_row5" class="row_heading level0 row5" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.9)</th>
#       <td id="T_5e22c_row5_col0" class="data row5 col0" >0.412565</td>
#     </tr>
#     <tr>
#       <th id="T_5e22c_level0_row6" class="row_heading level0 row6" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_5e22c_row6_col0" class="data row6 col0" >0.411843</td>
#     </tr>
#     <tr>
#       <th id="T_5e22c_level0_row7" class="row_heading level0 row7" >MaximumSequenceProbability</th>
#       <td id="T_5e22c_row7_col0" class="data row7 col0" >0.372873</td>
#     </tr>
#     <tr>
#       <th id="T_5e22c_level0_row8" class="row_heading level0 row8" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_5e22c_row8_col0" class="data row8 col0" >0.360804</td>
#     </tr>
#     <tr>
#       <th id="T_5e22c_level0_row9" class="row_heading level0 row9" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_5e22c_row9_col0" class="data row9 col0" >0.339123</td>
#     </tr>
#     <tr>
#       <th id="T_5e22c_level0_row10" class="row_heading level0 row10" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.9)</th>
#       <td id="T_5e22c_row10_col0" class="data row10 col0" >0.336194</td>
#     </tr>
#     <tr>
#       <th id="T_5e22c_level0_row11" class="row_heading level0 row11" >TokenMahalanobisDistance_decoder (sum, accuracy, 1.0)</th>
#       <td id="T_5e22c_row11_col0" class="data row11 col0" >0.308321</td>
#     </tr>
#     <tr>
#       <th id="T_5e22c_level0_row12" class="row_heading level0 row12" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.9)</th>
#       <td id="T_5e22c_row12_col0" class="data row12 col0" >0.307531</td>
#     </tr>
#     <tr>
#       <th id="T_5e22c_level0_row13" class="row_heading level0 row13" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_5e22c_row13_col0" class="data row13 col0" >0.295856</td>
#     </tr>
#     <tr>
#       <th id="T_5e22c_level0_row14" class="row_heading level0 row14" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.0)</th>
#       <td id="T_5e22c_row14_col0" class="data row14 col0" >0.290962</td>
#     </tr>
#     <tr>
#       <th id="T_5e22c_level0_row15" class="row_heading level0 row15" >MeanTokenEntropy</th>
#       <td id="T_5e22c_row15_col0" class="data row15 col0" >0.289029</td>
#     </tr>
#     <tr>
#       <th id="T_5e22c_level0_row16" class="row_heading level0 row16" >Perplexity</th>
#       <td id="T_5e22c_row16_col0" class="data row16 col0" >0.246434</td>
#     </tr>
#     <tr>
#       <th id="T_5e22c_level0_row17" class="row_heading level0 row17" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_5e22c_row17_col0" class="data row17 col0" >0.242661</td>
#     </tr>
#     <tr>
#       <th id="T_5e22c_level0_row18" class="row_heading level0 row18" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.0)</th>
#       <td id="T_5e22c_row18_col0" class="data row18 col0" >0.159473</td>
#     </tr>
#   </tbody>
# </table>

# %%
np.mean(man.gen_metrics[('sequence', 'Accuracy')])
# Out:
# 0.129

# %% [markdown]
# ## Vicuna 13b

# %%
path = "lm-polygraph/workdir/output/qa/lmsys/vicuna-13b-v1.5/['gsm8k', 'main']/2024-04-09/23-14-30/ue_manager_seed1"
man = UEManager.load(path)

metric_names = ['Accuracy']
df = {}
for key in man.metrics.keys():
    if (key[-1] == 'prr_normalized') and (key[-2] in metric_names):
        scores = df.get(key[1], [])
        scores.append(man.metrics[key])
        df[key[1]] = scores
        
df0 = pd.DataFrame(df, index=[f'GSM8k, {m}, PRR' for m in metric_names])  
df0.T.sort_values(f"GSM8k, {metric_names[-1]}, PRR", ascending=False).style.background_gradient(axis=0)
# Out:
# Stat calculators: [<lm_polygraph.stat_calculators.greedy_probs.GreedyProbsCalculator object at 0x7fc48b67cf40>]
# <style type="text/css">
# #T_4a0c4_row0_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_4a0c4_row1_col0 {
#   background-color: #034f7d;
#   color: #f1f1f1;
# }
# #T_4a0c4_row2_col0 {
#   background-color: #045585;
#   color: #f1f1f1;
# }
# #T_4a0c4_row3_col0 {
#   background-color: #045788;
#   color: #f1f1f1;
# }
# #T_4a0c4_row4_col0 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_4a0c4_row5_col0 {
#   background-color: #045c90;
#   color: #f1f1f1;
# }
# #T_4a0c4_row6_col0 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_4a0c4_row7_col0 {
#   background-color: #04629a;
#   color: #f1f1f1;
# }
# #T_4a0c4_row8_col0 {
#   background-color: #0566a0;
#   color: #f1f1f1;
# }
# #T_4a0c4_row9_col0, #T_4a0c4_row10_col0 {
#   background-color: #0569a4;
#   color: #f1f1f1;
# }
# #T_4a0c4_row11_col0 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_4a0c4_row12_col0 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_4a0c4_row13_col0 {
#   background-color: #4897c4;
#   color: #f1f1f1;
# }
# #T_4a0c4_row14_col0 {
#   background-color: #4a98c5;
#   color: #f1f1f1;
# }
# #T_4a0c4_row15_col0 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_4a0c4_row16_col0 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_4a0c4_row17_col0 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_4a0c4_row18_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_4a0c4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4a0c4_level0_col0" class="col_heading level0 col0" >GSM8k, Accuracy, PRR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a0c4_level0_row0" class="row_heading level0 row0" >TokenMahalanobisDistance_decoder (mean, accuracy, 1.0)</th>
#       <td id="T_4a0c4_row0_col0" class="data row0 col0" >0.581796</td>
#     </tr>
#     <tr>
#       <th id="T_4a0c4_level0_row1" class="row_heading level0 row1" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.9)</th>
#       <td id="T_4a0c4_row1_col0" class="data row1 col0" >0.542334</td>
#     </tr>
#     <tr>
#       <th id="T_4a0c4_level0_row2" class="row_heading level0 row2" >RelativeMahalanobisDistance_decoder (mean, accuracy, 1.0)</th>
#       <td id="T_4a0c4_row2_col0" class="data row2 col0" >0.531925</td>
#     </tr>
#     <tr>
#       <th id="T_4a0c4_level0_row3" class="row_heading level0 row3" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_4a0c4_row3_col0" class="data row3 col0" >0.528363</td>
#     </tr>
#     <tr>
#       <th id="T_4a0c4_level0_row4" class="row_heading level0 row4" >RelativeMahalanobisDistance_decoder (sum, accuracy, 1.0)</th>
#       <td id="T_4a0c4_row4_col0" class="data row4 col0" >0.522828</td>
#     </tr>
#     <tr>
#       <th id="T_4a0c4_level0_row5" class="row_heading level0 row5" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_4a0c4_row5_col0" class="data row5 col0" >0.518332</td>
#     </tr>
#     <tr>
#       <th id="T_4a0c4_level0_row6" class="row_heading level0 row6" >TokenMahalanobisDistance_decoder (sum, accuracy, 1.0)</th>
#       <td id="T_4a0c4_row6_col0" class="data row6 col0" >0.509051</td>
#     </tr>
#     <tr>
#       <th id="T_4a0c4_level0_row7" class="row_heading level0 row7" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.9)</th>
#       <td id="T_4a0c4_row7_col0" class="data row7 col0" >0.502940</td>
#     </tr>
#     <tr>
#       <th id="T_4a0c4_level0_row8" class="row_heading level0 row8" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_4a0c4_row8_col0" class="data row8 col0" >0.492718</td>
#     </tr>
#     <tr>
#       <th id="T_4a0c4_level0_row9" class="row_heading level0 row9" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.9)</th>
#       <td id="T_4a0c4_row9_col0" class="data row9 col0" >0.486378</td>
#     </tr>
#     <tr>
#       <th id="T_4a0c4_level0_row10" class="row_heading level0 row10" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.0)</th>
#       <td id="T_4a0c4_row10_col0" class="data row10 col0" >0.486167</td>
#     </tr>
#     <tr>
#       <th id="T_4a0c4_level0_row11" class="row_heading level0 row11" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.9)</th>
#       <td id="T_4a0c4_row11_col0" class="data row11 col0" >0.453236</td>
#     </tr>
#     <tr>
#       <th id="T_4a0c4_level0_row12" class="row_heading level0 row12" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_4a0c4_row12_col0" class="data row12 col0" >0.429311</td>
#     </tr>
#     <tr>
#       <th id="T_4a0c4_level0_row13" class="row_heading level0 row13" >MaximumSequenceProbability</th>
#       <td id="T_4a0c4_row13_col0" class="data row13 col0" >0.391946</td>
#     </tr>
#     <tr>
#       <th id="T_4a0c4_level0_row14" class="row_heading level0 row14" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_4a0c4_row14_col0" class="data row14 col0" >0.391618</td>
#     </tr>
#     <tr>
#       <th id="T_4a0c4_level0_row15" class="row_heading level0 row15" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_4a0c4_row15_col0" class="data row15 col0" >0.224470</td>
#     </tr>
#     <tr>
#       <th id="T_4a0c4_level0_row16" class="row_heading level0 row16" >Perplexity</th>
#       <td id="T_4a0c4_row16_col0" class="data row16 col0" >0.132614</td>
#     </tr>
#     <tr>
#       <th id="T_4a0c4_level0_row17" class="row_heading level0 row17" >MeanTokenEntropy</th>
#       <td id="T_4a0c4_row17_col0" class="data row17 col0" >0.127400</td>
#     </tr>
#     <tr>
#       <th id="T_4a0c4_level0_row18" class="row_heading level0 row18" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.0)</th>
#       <td id="T_4a0c4_row18_col0" class="data row18 col0" >0.123175</td>
#     </tr>
#   </tbody>
# </table>

# %%
np.mean(man.gen_metrics[('sequence', 'Accuracy')])
# Out:
# 0.191

# %% [markdown]
# ## Mistral 7b

# %%
path = "lm-polygraph/workdir/output/qa/alpindale/Mistral-7B-v0.2-hf/['gsm8k', 'main']/2024-04-09/23-14-29/ue_manager_seed1"
man = UEManager.load(path)

metric_names = ['Accuracy']
df = {}
for key in man.metrics.keys():
    if (key[-1] == 'prr_normalized') and (key[-2] in metric_names):
        scores = df.get(key[1], [])
        scores.append(man.metrics[key])
        df[key[1]] = scores
        
df0 = pd.DataFrame(df, index=[f'GSM8k, {m}, PRR' for m in metric_names])  
df0.T.sort_values(f"GSM8k, {metric_names[-1]}, PRR", ascending=False).style.background_gradient(axis=0)
# Out:
# Stat calculators: [<lm_polygraph.stat_calculators.greedy_probs.GreedyProbsCalculator object at 0x7fc48b67cf40>]
# <style type="text/css">
# #T_f0644_row0_col0, #T_f0644_row1_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_f0644_row2_col0, #T_f0644_row3_col0 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_f0644_row4_col0, #T_f0644_row5_col0 {
#   background-color: #023e62;
#   color: #f1f1f1;
# }
# #T_f0644_row6_col0, #T_f0644_row7_col0 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_f0644_row8_col0, #T_f0644_row9_col0 {
#   background-color: #034973;
#   color: #f1f1f1;
# }
# #T_f0644_row10_col0, #T_f0644_row11_col0 {
#   background-color: #045280;
#   color: #f1f1f1;
# }
# #T_f0644_row12_col0, #T_f0644_row13_col0 {
#   background-color: #045585;
#   color: #f1f1f1;
# }
# #T_f0644_row14_col0, #T_f0644_row15_col0 {
#   background-color: #045788;
#   color: #f1f1f1;
# }
# #T_f0644_row16_col0 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_f0644_row17_col0, #T_f0644_row18_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_f0644">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f0644_level0_col0" class="col_heading level0 col0" >GSM8k, Accuracy, PRR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f0644_level0_row0" class="row_heading level0 row0" >TokenMahalanobisDistance_decoder (mean, accuracy, 1.0)</th>
#       <td id="T_f0644_row0_col0" class="data row0 col0" >0.319444</td>
#     </tr>
#     <tr>
#       <th id="T_f0644_level0_row1" class="row_heading level0 row1" >TokenMahalanobisDistance_decoder (sum, accuracy, 1.0)</th>
#       <td id="T_f0644_row1_col0" class="data row1 col0" >0.319444</td>
#     </tr>
#     <tr>
#       <th id="T_f0644_level0_row2" class="row_heading level0 row2" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_f0644_row2_col0" class="data row2 col0" >0.310199</td>
#     </tr>
#     <tr>
#       <th id="T_f0644_level0_row3" class="row_heading level0 row3" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_f0644_row3_col0" class="data row3 col0" >0.310199</td>
#     </tr>
#     <tr>
#       <th id="T_f0644_level0_row4" class="row_heading level0 row4" >RelativeMahalanobisDistance_decoder (sum, accuracy, 1.0)</th>
#       <td id="T_f0644_row4_col0" class="data row4 col0" >0.307177</td>
#     </tr>
#     <tr>
#       <th id="T_f0644_level0_row5" class="row_heading level0 row5" >RelativeMahalanobisDistance_decoder (mean, accuracy, 1.0)</th>
#       <td id="T_f0644_row5_col0" class="data row5 col0" >0.307177</td>
#     </tr>
#     <tr>
#       <th id="T_f0644_level0_row6" class="row_heading level0 row6" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_f0644_row6_col0" class="data row6 col0" >0.299965</td>
#     </tr>
#     <tr>
#       <th id="T_f0644_level0_row7" class="row_heading level0 row7" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_f0644_row7_col0" class="data row7 col0" >0.299965</td>
#     </tr>
#     <tr>
#       <th id="T_f0644_level0_row8" class="row_heading level0 row8" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.0)</th>
#       <td id="T_f0644_row8_col0" class="data row8 col0" >0.287797</td>
#     </tr>
#     <tr>
#       <th id="T_f0644_level0_row9" class="row_heading level0 row9" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_f0644_row9_col0" class="data row9 col0" >0.287797</td>
#     </tr>
#     <tr>
#       <th id="T_f0644_level0_row10" class="row_heading level0 row10" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_f0644_row10_col0" class="data row10 col0" >0.272979</td>
#     </tr>
#     <tr>
#       <th id="T_f0644_level0_row11" class="row_heading level0 row11" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.0)</th>
#       <td id="T_f0644_row11_col0" class="data row11 col0" >0.272979</td>
#     </tr>
#     <tr>
#       <th id="T_f0644_level0_row12" class="row_heading level0 row12" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.9)</th>
#       <td id="T_f0644_row12_col0" class="data row12 col0" >0.268023</td>
#     </tr>
#     <tr>
#       <th id="T_f0644_level0_row13" class="row_heading level0 row13" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.9)</th>
#       <td id="T_f0644_row13_col0" class="data row13 col0" >0.268023</td>
#     </tr>
#     <tr>
#       <th id="T_f0644_level0_row14" class="row_heading level0 row14" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.9)</th>
#       <td id="T_f0644_row14_col0" class="data row14 col0" >0.263764</td>
#     </tr>
#     <tr>
#       <th id="T_f0644_level0_row15" class="row_heading level0 row15" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.9)</th>
#       <td id="T_f0644_row15_col0" class="data row15 col0" >0.263764</td>
#     </tr>
#     <tr>
#       <th id="T_f0644_level0_row16" class="row_heading level0 row16" >MeanTokenEntropy</th>
#       <td id="T_f0644_row16_col0" class="data row16 col0" >-0.150315</td>
#     </tr>
#     <tr>
#       <th id="T_f0644_level0_row17" class="row_heading level0 row17" >Perplexity</th>
#       <td id="T_f0644_row17_col0" class="data row17 col0" >-0.160396</td>
#     </tr>
#     <tr>
#       <th id="T_f0644_level0_row18" class="row_heading level0 row18" >MaximumSequenceProbability</th>
#       <td id="T_f0644_row18_col0" class="data row18 col0" >-0.160396</td>
#     </tr>
#   </tbody>
# </table>

# %%
np.mean(man.gen_metrics[('sequence', 'Accuracy')])
# Out:
# 0.323

# %% [markdown]
# # XSUM

# %% [markdown]
# ## Vicuna 7b

# %%
path = "lm-polygraph/workdir/output/ats/lmsys/vicuna-7b-v1.5/xsum/2024-04-09/23-14-30/ue_manager_seed1"
man = UEManager.load(path)

metric_names = ['Rouge_rougeL', 'AlignScore']
df = {}
for key in man.metrics.keys():
    if (key[-1] == 'prr_normalized') and (key[-2] in metric_names):
        scores = df.get(key[1], [])
        scores.append(man.metrics[key])
        df[key[1]] = scores
        
df0 = pd.DataFrame(df, index=[f'XSUM, {m}, PRR' for m in metric_names])  
df0.T.sort_values(f"XSUM, {metric_names[-1]}, PRR", ascending=False).style.background_gradient(axis=0)
# Out:
# Stat calculators: [<lm_polygraph.stat_calculators.greedy_probs.GreedyProbsCalculator object at 0x7fc48b67cf40>]
# <style type="text/css">
# #T_36550_row0_col0 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_36550_row0_col1, #T_36550_row2_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_36550_row1_col0 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_36550_row1_col1, #T_36550_row2_col1 {
#   background-color: #046198;
#   color: #f1f1f1;
# }
# #T_36550_row3_col0 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_36550_row3_col1 {
#   background-color: #056fae;
#   color: #f1f1f1;
# }
# #T_36550_row4_col0 {
#   background-color: #65a3cb;
#   color: #f1f1f1;
# }
# #T_36550_row4_col1 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_36550_row5_col0 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_36550_row5_col1 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_36550_row6_col0, #T_36550_row10_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_36550_row6_col1 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_36550_row7_col0 {
#   background-color: #2c89bd;
#   color: #f1f1f1;
# }
# #T_36550_row7_col1 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_36550_row8_col0 {
#   background-color: #2182b9;
#   color: #f1f1f1;
# }
# #T_36550_row8_col1 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_36550_row9_col0 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_36550_row9_col1 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_36550_row10_col0 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# </style>
# <table id="T_36550">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_36550_level0_col0" class="col_heading level0 col0" >XSUM, Rouge_rougeL, PRR</th>
#       <th id="T_36550_level0_col1" class="col_heading level0 col1" >XSUM, AlignScore, PRR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_36550_level0_row0" class="row_heading level0 row0" >MeanTokenEntropy</th>
#       <td id="T_36550_row0_col0" class="data row0 col0" >0.024997</td>
#       <td id="T_36550_row0_col1" class="data row0 col1" >0.148440</td>
#     </tr>
#     <tr>
#       <th id="T_36550_level0_row1" class="row_heading level0 row1" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_36550_row1_col0" class="data row1 col0" >0.075167</td>
#       <td id="T_36550_row1_col1" class="data row1 col1" >0.109446</td>
#     </tr>
#     <tr>
#       <th id="T_36550_level0_row2" class="row_heading level0 row2" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_36550_row2_col0" class="data row2 col0" >0.126173</td>
#       <td id="T_36550_row2_col1" class="data row2 col1" >0.109117</td>
#     </tr>
#     <tr>
#       <th id="T_36550_level0_row3" class="row_heading level0 row3" >Perplexity</th>
#       <td id="T_36550_row3_col0" class="data row3 col0" >0.017226</td>
#       <td id="T_36550_row3_col1" class="data row3 col1" >0.090535</td>
#     </tr>
#     <tr>
#       <th id="T_36550_level0_row4" class="row_heading level0 row4" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.0)</th>
#       <td id="T_36550_row4_col0" class="data row4 col0" >0.040631</td>
#       <td id="T_36550_row4_col1" class="data row4 col1" >0.020652</td>
#     </tr>
#     <tr>
#       <th id="T_36550_level0_row5" class="row_heading level0 row5" >MaximumSequenceProbability</th>
#       <td id="T_36550_row5_col0" class="data row5 col0" >-0.009734</td>
#       <td id="T_36550_row5_col1" class="data row5 col1" >0.019434</td>
#     </tr>
#     <tr>
#       <th id="T_36550_level0_row6" class="row_heading level0 row6" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_36550_row6_col0" class="data row6 col0" >-0.055818</td>
#       <td id="T_36550_row6_col1" class="data row6 col1" >0.000061</td>
#     </tr>
#     <tr>
#       <th id="T_36550_level0_row7" class="row_heading level0 row7" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_36550_row7_col0" class="data row7 col0" >0.062274</td>
#       <td id="T_36550_row7_col1" class="data row7 col1" >-0.038587</td>
#     </tr>
#     <tr>
#       <th id="T_36550_level0_row8" class="row_heading level0 row8" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_36550_row8_col0" class="data row8 col0" >0.067524</td>
#       <td id="T_36550_row8_col1" class="data row8 col1" >-0.050990</td>
#     </tr>
#     <tr>
#       <th id="T_36550_level0_row9" class="row_heading level0 row9" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_36550_row9_col0" class="data row9 col0" >0.037828</td>
#       <td id="T_36550_row9_col1" class="data row9 col1" >-0.059794</td>
#     </tr>
#     <tr>
#       <th id="T_36550_level0_row10" class="row_heading level0 row10" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.0)</th>
#       <td id="T_36550_row10_col0" class="data row10 col0" >0.019616</td>
#       <td id="T_36550_row10_col1" class="data row10 col1" >-0.087947</td>
#     </tr>
#   </tbody>
# </table>

# %%
np.mean(man.gen_metrics[('sequence', 'AlignScore')])
# Out:
# 0.0621609894928406

# %% [markdown]
# ## Vicuna 13b

# %%
path = "lm-polygraph/workdir/output/ats/lmsys/vicuna-13b-v1.5/xsum/2024-04-09/23-14-29/ue_manager_seed1"
man = UEManager.load(path)

metric_names = ['Rouge_rougeL', 'AlignScore']
df = {}
for key in man.metrics.keys():
    if (key[-1] == 'prr_normalized') and (key[-2] in metric_names):
        scores = df.get(key[1], [])
        scores.append(man.metrics[key])
        df[key[1]] = scores
        
df0 = pd.DataFrame(df, index=[f'XSUM, {m}, PRR' for m in metric_names])  
df0.T.sort_values(f"XSUM, {metric_names[-1]}, PRR", ascending=False).style.background_gradient(axis=0)
# Out:
# Stat calculators: [<lm_polygraph.stat_calculators.greedy_probs.GreedyProbsCalculator object at 0x7fc48b67cf40>]
# <style type="text/css">
# #T_d47a4_row0_col0 {
#   background-color: #3b92c1;
#   color: #f1f1f1;
# }
# #T_d47a4_row0_col1, #T_d47a4_row6_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_d47a4_row1_col0 {
#   background-color: #045585;
#   color: #f1f1f1;
# }
# #T_d47a4_row1_col1 {
#   background-color: #045280;
#   color: #f1f1f1;
# }
# #T_d47a4_row2_col0 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_d47a4_row2_col1 {
#   background-color: #04629a;
#   color: #f1f1f1;
# }
# #T_d47a4_row3_col0 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_d47a4_row3_col1 {
#   background-color: #0771b1;
#   color: #f1f1f1;
# }
# #T_d47a4_row4_col0 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_d47a4_row4_col1 {
#   background-color: #2383ba;
#   color: #f1f1f1;
# }
# #T_d47a4_row5_col0 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_d47a4_row5_col1 {
#   background-color: #348ebf;
#   color: #f1f1f1;
# }
# #T_d47a4_row6_col1 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_d47a4_row7_col0 {
#   background-color: #04588a;
#   color: #f1f1f1;
# }
# #T_d47a4_row7_col1 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_d47a4_row8_col0 {
#   background-color: #056fae;
#   color: #f1f1f1;
# }
# #T_d47a4_row8_col1 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_d47a4_row9_col0, #T_d47a4_row10_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_d47a4_row9_col1 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_d47a4_row10_col0 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d47a4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d47a4_level0_col0" class="col_heading level0 col0" >XSUM, Rouge_rougeL, PRR</th>
#       <th id="T_d47a4_level0_col1" class="col_heading level0 col1" >XSUM, AlignScore, PRR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d47a4_level0_row0" class="row_heading level0 row0" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_d47a4_row0_col0" class="data row0 col0" >0.127219</td>
#       <td id="T_d47a4_row0_col1" class="data row0 col1" >0.187453</td>
#     </tr>
#     <tr>
#       <th id="T_d47a4_level0_row1" class="row_heading level0 row1" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_d47a4_row1_col0" class="data row1 col0" >0.160918</td>
#       <td id="T_d47a4_row1_col1" class="data row1 col1" >0.167808</td>
#     </tr>
#     <tr>
#       <th id="T_d47a4_level0_row2" class="row_heading level0 row2" >MeanTokenEntropy</th>
#       <td id="T_d47a4_row2_col0" class="data row2 col0" >0.088062</td>
#       <td id="T_d47a4_row2_col1" class="data row2 col1" >0.151454</td>
#     </tr>
#     <tr>
#       <th id="T_d47a4_level0_row3" class="row_heading level0 row3" >Perplexity</th>
#       <td id="T_d47a4_row3_col0" class="data row3 col0" >0.084116</td>
#       <td id="T_d47a4_row3_col1" class="data row3 col1" >0.135020</td>
#     </tr>
#     <tr>
#       <th id="T_d47a4_level0_row4" class="row_heading level0 row4" >MaximumSequenceProbability</th>
#       <td id="T_d47a4_row4_col0" class="data row4 col0" >0.135675</td>
#       <td id="T_d47a4_row4_col1" class="data row4 col1" >0.120805</td>
#     </tr>
#     <tr>
#       <th id="T_d47a4_level0_row5" class="row_heading level0 row5" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_d47a4_row5_col0" class="data row5 col0" >0.085816</td>
#       <td id="T_d47a4_row5_col1" class="data row5 col1" >0.112239</td>
#     </tr>
#     <tr>
#       <th id="T_d47a4_level0_row6" class="row_heading level0 row6" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_d47a4_row6_col0" class="data row6 col0" >0.173773</td>
#       <td id="T_d47a4_row6_col1" class="data row6 col1" >0.081399</td>
#     </tr>
#     <tr>
#       <th id="T_d47a4_level0_row7" class="row_heading level0 row7" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_d47a4_row7_col0" class="data row7 col0" >0.159304</td>
#       <td id="T_d47a4_row7_col1" class="data row7 col1" >0.056370</td>
#     </tr>
#     <tr>
#       <th id="T_d47a4_level0_row8" class="row_heading level0 row8" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.0)</th>
#       <td id="T_d47a4_row8_col0" class="data row8 col0" >0.144362</td>
#       <td id="T_d47a4_row8_col1" class="data row8 col1" >0.023399</td>
#     </tr>
#     <tr>
#       <th id="T_d47a4_level0_row9" class="row_heading level0 row9" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.0)</th>
#       <td id="T_d47a4_row9_col0" class="data row9 col0" >0.052968</td>
#       <td id="T_d47a4_row9_col1" class="data row9 col1" >-0.013338</td>
#     </tr>
#     <tr>
#       <th id="T_d47a4_level0_row10" class="row_heading level0 row10" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_d47a4_row10_col0" class="data row10 col0" >0.133248</td>
#       <td id="T_d47a4_row10_col1" class="data row10 col1" >-0.017376</td>
#     </tr>
#   </tbody>
# </table>

# %%
np.mean(man.gen_metrics[('sequence', 'AlignScore')])
# Out:
# 0.08629431277797267

# %% [markdown]
# ## Mistral 7b

# %%
path = "lm-polygraph/workdir/output/ats/alpindale/Mistral-7B-v0.2-hf/xsum/2024-04-09/23-14-31/ue_manager_seed1"
man = UEManager.load(path)

metric_names = ['Rouge_rougeL', 'AlignScore']
df = {}
for key in man.metrics.keys():
    if (key[-1] == 'prr_normalized') and (key[-2] in metric_names):
        scores = df.get(key[1], [])
        scores.append(man.metrics[key])
        df[key[1]] = scores
        
df0 = pd.DataFrame(df, index=[f'XSUM, {m}, PRR' for m in metric_names])  
df0.T.sort_values(f"XSUM, {metric_names[-1]}, PRR", ascending=False).style.background_gradient(axis=0)
# Out:
# Stat calculators: [<lm_polygraph.stat_calculators.greedy_probs.GreedyProbsCalculator object at 0x7fc48b67cf40>]
# <style type="text/css">
# #T_d06c8_row0_col0 {
#   background-color: #03446a;
#   color: #f1f1f1;
# }
# #T_d06c8_row0_col1, #T_d06c8_row4_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_d06c8_row1_col0 {
#   background-color: #023e62;
#   color: #f1f1f1;
# }
# #T_d06c8_row1_col1 {
#   background-color: #04649e;
#   color: #f1f1f1;
# }
# #T_d06c8_row2_col0 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_d06c8_row2_col1 {
#   background-color: #157ab5;
#   color: #f1f1f1;
# }
# #T_d06c8_row3_col0 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_d06c8_row3_col1 {
#   background-color: #187cb6;
#   color: #f1f1f1;
# }
# #T_d06c8_row4_col1 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_d06c8_row5_col0, #T_d06c8_row10_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_d06c8_row5_col1 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_d06c8_row6_col0 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_d06c8_row6_col1 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_d06c8_row7_col0 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_d06c8_row7_col1 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_d06c8_row8_col0 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_d06c8_row8_col1 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_d06c8_row9_col0 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_d06c8_row9_col1 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_d06c8_row10_col0 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# </style>
# <table id="T_d06c8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d06c8_level0_col0" class="col_heading level0 col0" >XSUM, Rouge_rougeL, PRR</th>
#       <th id="T_d06c8_level0_col1" class="col_heading level0 col1" >XSUM, AlignScore, PRR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d06c8_level0_row0" class="row_heading level0 row0" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_d06c8_row0_col0" class="data row0 col0" >0.334371</td>
#       <td id="T_d06c8_row0_col1" class="data row0 col1" >0.103817</td>
#     </tr>
#     <tr>
#       <th id="T_d06c8_level0_row1" class="row_heading level0 row1" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_d06c8_row1_col0" class="data row1 col0" >0.347345</td>
#       <td id="T_d06c8_row1_col1" class="data row1 col1" >0.080410</td>
#     </tr>
#     <tr>
#       <th id="T_d06c8_level0_row2" class="row_heading level0 row2" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_d06c8_row2_col0" class="data row2 col0" >-0.194326</td>
#       <td id="T_d06c8_row2_col1" class="data row2 col1" >0.067441</td>
#     </tr>
#     <tr>
#       <th id="T_d06c8_level0_row3" class="row_heading level0 row3" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_d06c8_row3_col0" class="data row3 col0" >-0.189549</td>
#       <td id="T_d06c8_row3_col1" class="data row3 col1" >0.066426</td>
#     </tr>
#     <tr>
#       <th id="T_d06c8_level0_row4" class="row_heading level0 row4" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.0)</th>
#       <td id="T_d06c8_row4_col0" class="data row4 col0" >0.365192</td>
#       <td id="T_d06c8_row4_col1" class="data row4 col1" >0.014786</td>
#     </tr>
#     <tr>
#       <th id="T_d06c8_level0_row5" class="row_heading level0 row5" >Perplexity</th>
#       <td id="T_d06c8_row5_col0" class="data row5 col0" >-0.295978</td>
#       <td id="T_d06c8_row5_col1" class="data row5 col1" >0.013115</td>
#     </tr>
#     <tr>
#       <th id="T_d06c8_level0_row6" class="row_heading level0 row6" >MeanTokenEntropy</th>
#       <td id="T_d06c8_row6_col0" class="data row6 col0" >-0.274470</td>
#       <td id="T_d06c8_row6_col1" class="data row6 col1" >0.009041</td>
#     </tr>
#     <tr>
#       <th id="T_d06c8_level0_row7" class="row_heading level0 row7" >MaximumSequenceProbability</th>
#       <td id="T_d06c8_row7_col0" class="data row7 col0" >-0.092869</td>
#       <td id="T_d06c8_row7_col1" class="data row7 col1" >-0.001631</td>
#     </tr>
#     <tr>
#       <th id="T_d06c8_level0_row8" class="row_heading level0 row8" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_d06c8_row8_col0" class="data row8 col0" >-0.213619</td>
#       <td id="T_d06c8_row8_col1" class="data row8 col1" >-0.019585</td>
#     </tr>
#     <tr>
#       <th id="T_d06c8_level0_row9" class="row_heading level0 row9" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_d06c8_row9_col0" class="data row9 col0" >-0.019231</td>
#       <td id="T_d06c8_row9_col1" class="data row9 col1" >-0.020377</td>
#     </tr>
#     <tr>
#       <th id="T_d06c8_level0_row10" class="row_heading level0 row10" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.0)</th>
#       <td id="T_d06c8_row10_col0" class="data row10 col0" >-0.096226</td>
#       <td id="T_d06c8_row10_col1" class="data row10 col1" >-0.021199</td>
#     </tr>
#   </tbody>
# </table>

# %%
np.mean(man.gen_metrics[('sequence', 'AlignScore')]), np.mean(man.gen_metrics[('sequence', 'Rouge_rougeL')])
# Out:
# (0.034991165048508265, 0.20618126565166967)

# %% [markdown]
# ## Stablm 12b

# %%
path = "lm-polygraph/workdir/output/ats/stabilityai/stablelm-2-12b/xsum/2024-04-10/05-39-18/ue_manager_seed1"
man = UEManager.load(path)

metric_names = ['Rouge_rougeL', 'AlignScore']
df = {}
for key in man.metrics.keys():
    if (key[-1] == 'prr_normalized') and (key[-2] in metric_names):
        scores = df.get(key[1], [])
        scores.append(man.metrics[key])
        df[key[1]] = scores
        
df0 = pd.DataFrame(df, index=[f'XSUM, {m}, PRR' for m in metric_names])  
df0.T.sort_values(f"XSUM, {metric_names[-1]}, PRR", ascending=False).style.background_gradient(axis=0)
# Out:
# Stat calculators: [<lm_polygraph.stat_calculators.greedy_probs.GreedyProbsCalculator object at 0x7fc48b67cf40>]
# <style type="text/css">
# #T_ee54c_row0_col0, #T_ee54c_row10_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_ee54c_row0_col1, #T_ee54c_row9_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_ee54c_row1_col0 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_ee54c_row1_col1, #T_ee54c_row7_col0 {
#   background-color: #03446a;
#   color: #f1f1f1;
# }
# #T_ee54c_row2_col0 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_ee54c_row2_col1 {
#   background-color: #046097;
#   color: #f1f1f1;
# }
# #T_ee54c_row3_col0 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_ee54c_row3_col1 {
#   background-color: #056aa6;
#   color: #f1f1f1;
# }
# #T_ee54c_row4_col0 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_ee54c_row4_col1 {
#   background-color: #0570b0;
#   color: #f1f1f1;
# }
# #T_ee54c_row5_col0 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_ee54c_row5_col1 {
#   background-color: #529bc7;
#   color: #f1f1f1;
# }
# #T_ee54c_row6_col0 {
#   background-color: #4496c3;
#   color: #f1f1f1;
# }
# #T_ee54c_row6_col1 {
#   background-color: #60a1ca;
#   color: #f1f1f1;
# }
# #T_ee54c_row7_col1, #T_ee54c_row8_col1 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_ee54c_row8_col0 {
#   background-color: #03456c;
#   color: #f1f1f1;
# }
# #T_ee54c_row9_col1 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_ee54c_row10_col0 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ee54c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ee54c_level0_col0" class="col_heading level0 col0" >XSUM, Rouge_rougeL, PRR</th>
#       <th id="T_ee54c_level0_col1" class="col_heading level0 col1" >XSUM, AlignScore, PRR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ee54c_level0_row0" class="row_heading level0 row0" >Perplexity</th>
#       <td id="T_ee54c_row0_col0" class="data row0 col0" >-0.094104</td>
#       <td id="T_ee54c_row0_col1" class="data row0 col1" >0.073626</td>
#     </tr>
#     <tr>
#       <th id="T_ee54c_level0_row1" class="row_heading level0 row1" >MeanTokenEntropy</th>
#       <td id="T_ee54c_row1_col0" class="data row1 col0" >-0.086495</td>
#       <td id="T_ee54c_row1_col1" class="data row1 col1" >0.066653</td>
#     </tr>
#     <tr>
#       <th id="T_ee54c_level0_row2" class="row_heading level0 row2" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_ee54c_row2_col0" class="data row2 col0" >-0.040553</td>
#       <td id="T_ee54c_row2_col1" class="data row2 col1" >0.048430</td>
#     </tr>
#     <tr>
#       <th id="T_ee54c_level0_row3" class="row_heading level0 row3" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_ee54c_row3_col0" class="data row3 col0" >0.022527</td>
#       <td id="T_ee54c_row3_col1" class="data row3 col1" >0.039754</td>
#     </tr>
#     <tr>
#       <th id="T_ee54c_level0_row4" class="row_heading level0 row4" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.0)</th>
#       <td id="T_ee54c_row4_col0" class="data row4 col0" >-0.033884</td>
#       <td id="T_ee54c_row4_col1" class="data row4 col1" >0.034142</td>
#     </tr>
#     <tr>
#       <th id="T_ee54c_level0_row5" class="row_heading level0 row5" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_ee54c_row5_col0" class="data row5 col0" >-0.025711</td>
#       <td id="T_ee54c_row5_col1" class="data row5 col1" >0.006194</td>
#     </tr>
#     <tr>
#       <th id="T_ee54c_level0_row6" class="row_heading level0 row6" >MaximumSequenceProbability</th>
#       <td id="T_ee54c_row6_col0" class="data row6 col0" >0.156525</td>
#       <td id="T_ee54c_row6_col1" class="data row6 col1" >0.001631</td>
#     </tr>
#     <tr>
#       <th id="T_ee54c_level0_row7" class="row_heading level0 row7" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_ee54c_row7_col0" class="data row7 col0" >0.308204</td>
#       <td id="T_ee54c_row7_col1" class="data row7 col1" >-0.055999</td>
#     </tr>
#     <tr>
#       <th id="T_ee54c_level0_row8" class="row_heading level0 row8" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_ee54c_row8_col0" class="data row8 col0" >0.307004</td>
#       <td id="T_ee54c_row8_col1" class="data row8 col1" >-0.056375</td>
#     </tr>
#     <tr>
#       <th id="T_ee54c_level0_row9" class="row_heading level0 row9" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.0)</th>
#       <td id="T_ee54c_row9_col0" class="data row9 col0" >0.326880</td>
#       <td id="T_ee54c_row9_col1" class="data row9 col1" >-0.069938</td>
#     </tr>
#     <tr>
#       <th id="T_ee54c_level0_row10" class="row_heading level0 row10" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_ee54c_row10_col0" class="data row10 col0" >0.242592</td>
#       <td id="T_ee54c_row10_col1" class="data row10 col1" >-0.082828</td>
#     </tr>
#   </tbody>
# </table>

# %%
np.mean(man.gen_metrics[('sequence', 'AlignScore')])
# Out:
# 0.08725634816825187

# %% [markdown]
# # WMT 14 De-En

# %% [markdown]
# ## Vicuna 7b

# %%
path = "lm-polygraph/workdir/output/nmt/lmsys/vicuna-7b-v1.5/['wmt14', 'de-en']/2024-04-09/23-14-31/ue_manager_seed1"
man = UEManager.load(path)

metric_names = ['Comet', 'AlignScore']
df = {}
for key in man.metrics.keys():
    if (key[-1] == 'prr_normalized') and (key[-2] in metric_names):
        scores = df.get(key[1], [])
        scores.append(man.metrics[key])
        df[key[1]] = scores
        
df0 = pd.DataFrame(df, index=[f'WMT14 De-En, {m}, PRR' for m in metric_names])  
df0.T.sort_values(f"WMT14 De-En, {metric_names[-1]}, PRR", ascending=False).style.background_gradient(axis=0)
# Out:
# Stat calculators: [<lm_polygraph.stat_calculators.greedy_probs.GreedyProbsCalculator object at 0x7fc48b67cf40>]
# <style type="text/css">
# #T_ce0c5_row0_col0, #T_ce0c5_row0_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_ce0c5_row1_col0 {
#   background-color: #0567a1;
#   color: #f1f1f1;
# }
# #T_ce0c5_row1_col1 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_ce0c5_row2_col0 {
#   background-color: #045e93;
#   color: #f1f1f1;
# }
# #T_ce0c5_row2_col1 {
#   background-color: #045d92;
#   color: #f1f1f1;
# }
# #T_ce0c5_row3_col0 {
#   background-color: #308cbe;
#   color: #f1f1f1;
# }
# #T_ce0c5_row3_col1 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_ce0c5_row4_col0 {
#   background-color: #3b92c1;
#   color: #f1f1f1;
# }
# #T_ce0c5_row4_col1 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_ce0c5_row5_col0 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_ce0c5_row5_col1, #T_ce0c5_row6_col1 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_ce0c5_row6_col0 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_ce0c5_row7_col0 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_ce0c5_row7_col1 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_ce0c5_row8_col0 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_ce0c5_row8_col1 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_ce0c5_row9_col0 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_ce0c5_row9_col1, #T_ce0c5_row10_col0, #T_ce0c5_row10_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_ce0c5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ce0c5_level0_col0" class="col_heading level0 col0" >WMT14 De-En, Comet, PRR</th>
#       <th id="T_ce0c5_level0_col1" class="col_heading level0 col1" >WMT14 De-En, AlignScore, PRR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce0c5_level0_row0" class="row_heading level0 row0" >MeanTokenEntropy</th>
#       <td id="T_ce0c5_row0_col0" class="data row0 col0" >0.274388</td>
#       <td id="T_ce0c5_row0_col1" class="data row0 col1" >0.551702</td>
#     </tr>
#     <tr>
#       <th id="T_ce0c5_level0_row1" class="row_heading level0 row1" >Perplexity</th>
#       <td id="T_ce0c5_row1_col0" class="data row1 col0" >0.233358</td>
#       <td id="T_ce0c5_row1_col1" class="data row1 col1" >0.512977</td>
#     </tr>
#     <tr>
#       <th id="T_ce0c5_level0_row2" class="row_heading level0 row2" >MaximumSequenceProbability</th>
#       <td id="T_ce0c5_row2_col0" class="data row2 col0" >0.244103</td>
#       <td id="T_ce0c5_row2_col1" class="data row2 col1" >0.480413</td>
#     </tr>
#     <tr>
#       <th id="T_ce0c5_level0_row3" class="row_heading level0 row3" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_ce0c5_row3_col0" class="data row3 col0" >0.199104</td>
#       <td id="T_ce0c5_row3_col1" class="data row3 col1" >0.224835</td>
#     </tr>
#     <tr>
#       <th id="T_ce0c5_level0_row4" class="row_heading level0 row4" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_ce0c5_row4_col0" class="data row4 col0" >0.193842</td>
#       <td id="T_ce0c5_row4_col1" class="data row4 col1" >0.223493</td>
#     </tr>
#     <tr>
#       <th id="T_ce0c5_level0_row5" class="row_heading level0 row5" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_ce0c5_row5_col0" class="data row5 col0" >0.143306</td>
#       <td id="T_ce0c5_row5_col1" class="data row5 col1" >0.116263</td>
#     </tr>
#     <tr>
#       <th id="T_ce0c5_level0_row6" class="row_heading level0 row6" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_ce0c5_row6_col0" class="data row6 col0" >0.140829</td>
#       <td id="T_ce0c5_row6_col1" class="data row6 col1" >0.114453</td>
#     </tr>
#     <tr>
#       <th id="T_ce0c5_level0_row7" class="row_heading level0 row7" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_ce0c5_row7_col0" class="data row7 col0" >0.131894</td>
#       <td id="T_ce0c5_row7_col1" class="data row7 col1" >0.109233</td>
#     </tr>
#     <tr>
#       <th id="T_ce0c5_level0_row8" class="row_heading level0 row8" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.0)</th>
#       <td id="T_ce0c5_row8_col0" class="data row8 col0" >0.136024</td>
#       <td id="T_ce0c5_row8_col1" class="data row8 col1" >0.101627</td>
#     </tr>
#     <tr>
#       <th id="T_ce0c5_level0_row9" class="row_heading level0 row9" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_ce0c5_row9_col0" class="data row9 col0" >0.068077</td>
#       <td id="T_ce0c5_row9_col1" class="data row9 col1" >0.048075</td>
#     </tr>
#     <tr>
#       <th id="T_ce0c5_level0_row10" class="row_heading level0 row10" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.0)</th>
#       <td id="T_ce0c5_row10_col0" class="data row10 col0" >0.065628</td>
#       <td id="T_ce0c5_row10_col1" class="data row10 col1" >0.047476</td>
#     </tr>
#   </tbody>
# </table>

# %%
np.mean(man.gen_metrics[('sequence', 'Comet')])
# Out:
# 0.8373594695329666

# %%
path = "lm-polygraph/workdir/output/nmt/lmsys/vicuna-13b-v1.5/['wmt14', 'de-en']/2024-04-09/23-14-31/ue_manager_seed1"
man = UEManager.load(path)

metric_names = ['Comet', 'AlignScore']
df = {}
for key in man.metrics.keys():
    if (key[-1] == 'prr_normalized') and (key[-2] in metric_names):
        scores = df.get(key[1], [])
        scores.append(man.metrics[key])
        df[key[1]] = scores
        
df0 = pd.DataFrame(df, index=[f'WMT14 De-En, {m}, PRR' for m in metric_names])  
df0.T.sort_values(f"WMT14 De-En, {metric_names[-1]}, PRR", ascending=False).style.background_gradient(axis=0)
# Out:
# Stat calculators: [<lm_polygraph.stat_calculators.greedy_probs.GreedyProbsCalculator object at 0x7fc48b67cf40>]
# <style type="text/css">
# #T_dcd16_row0_col0, #T_dcd16_row0_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_dcd16_row1_col0 {
#   background-color: #034f7d;
#   color: #f1f1f1;
# }
# #T_dcd16_row1_col1 {
#   background-color: #03517e;
#   color: #f1f1f1;
# }
# #T_dcd16_row2_col0 {
#   background-color: #05659f;
#   color: #f1f1f1;
# }
# #T_dcd16_row2_col1 {
#   background-color: #0569a4;
#   color: #f1f1f1;
# }
# #T_dcd16_row3_col0 {
#   background-color: #045b8e;
#   color: #f1f1f1;
# }
# #T_dcd16_row3_col1, #T_dcd16_row4_col1 {
#   background-color: #3790c0;
#   color: #f1f1f1;
# }
# #T_dcd16_row4_col0 {
#   background-color: #045788;
#   color: #f1f1f1;
# }
# #T_dcd16_row5_col0 {
#   background-color: #4897c4;
#   color: #f1f1f1;
# }
# #T_dcd16_row5_col1 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_dcd16_row6_col0 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_dcd16_row6_col1 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_dcd16_row7_col0 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_dcd16_row7_col1 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_dcd16_row8_col0 {
#   background-color: #529bc7;
#   color: #f1f1f1;
# }
# #T_dcd16_row8_col1 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_dcd16_row9_col0, #T_dcd16_row9_col1, #T_dcd16_row10_col0, #T_dcd16_row10_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_dcd16">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dcd16_level0_col0" class="col_heading level0 col0" >WMT14 De-En, Comet, PRR</th>
#       <th id="T_dcd16_level0_col1" class="col_heading level0 col1" >WMT14 De-En, AlignScore, PRR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dcd16_level0_row0" class="row_heading level0 row0" >MeanTokenEntropy</th>
#       <td id="T_dcd16_row0_col0" class="data row0 col0" >0.258356</td>
#       <td id="T_dcd16_row0_col1" class="data row0 col1" >0.542357</td>
#     </tr>
#     <tr>
#       <th id="T_dcd16_level0_row1" class="row_heading level0 row1" >Perplexity</th>
#       <td id="T_dcd16_row1_col0" class="data row1 col0" >0.238769</td>
#       <td id="T_dcd16_row1_col1" class="data row1 col1" >0.493736</td>
#     </tr>
#     <tr>
#       <th id="T_dcd16_level0_row2" class="row_heading level0 row2" >MaximumSequenceProbability</th>
#       <td id="T_dcd16_row2_col0" class="data row2 col0" >0.216374</td>
#       <td id="T_dcd16_row2_col1" class="data row2 col1" >0.431071</td>
#     </tr>
#     <tr>
#       <th id="T_dcd16_level0_row3" class="row_heading level0 row3" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_dcd16_row3_col0" class="data row3 col0" >0.229777</td>
#       <td id="T_dcd16_row3_col1" class="data row3 col1" >0.342794</td>
#     </tr>
#     <tr>
#       <th id="T_dcd16_level0_row4" class="row_heading level0 row4" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_dcd16_row4_col0" class="data row4 col0" >0.232429</td>
#       <td id="T_dcd16_row4_col1" class="data row4 col1" >0.341478</td>
#     </tr>
#     <tr>
#       <th id="T_dcd16_level0_row5" class="row_heading level0 row5" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_dcd16_row5_col0" class="data row5 col0" >0.166717</td>
#       <td id="T_dcd16_row5_col1" class="data row5 col1" >0.157677</td>
#     </tr>
#     <tr>
#       <th id="T_dcd16_level0_row6" class="row_heading level0 row6" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_dcd16_row6_col0" class="data row6 col0" >0.163551</td>
#       <td id="T_dcd16_row6_col1" class="data row6 col1" >0.154636</td>
#     </tr>
#     <tr>
#       <th id="T_dcd16_level0_row7" class="row_heading level0 row7" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_dcd16_row7_col0" class="data row7 col0" >0.165375</td>
#       <td id="T_dcd16_row7_col1" class="data row7 col1" >0.123471</td>
#     </tr>
#     <tr>
#       <th id="T_dcd16_level0_row8" class="row_heading level0 row8" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.0)</th>
#       <td id="T_dcd16_row8_col0" class="data row8 col0" >0.162751</td>
#       <td id="T_dcd16_row8_col1" class="data row8 col1" >0.115593</td>
#     </tr>
#     <tr>
#       <th id="T_dcd16_level0_row9" class="row_heading level0 row9" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.0)</th>
#       <td id="T_dcd16_row9_col0" class="data row9 col0" >0.036914</td>
#       <td id="T_dcd16_row9_col1" class="data row9 col1" >0.010969</td>
#     </tr>
#     <tr>
#       <th id="T_dcd16_level0_row10" class="row_heading level0 row10" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_dcd16_row10_col0" class="data row10 col0" >0.037585</td>
#       <td id="T_dcd16_row10_col1" class="data row10 col1" >0.010951</td>
#     </tr>
#   </tbody>
# </table>

# %%
np.mean(man.gen_metrics[('sequence', 'Comet')])
# Out:
# 0.8482999328076839

# %% [markdown]
# ## Mistral 7b

# %%
path = "lm-polygraph/workdir/output/nmt/alpindale/Mistral-7B-v0.2-hf/['wmt14', 'de-en']/2024-04-10/05-39-15/ue_manager_seed1"
man = UEManager.load(path)

metric_names = ['Comet', 'AlignScore']
df = {}
for key in man.metrics.keys():
    if (key[-1] == 'prr_normalized') and (key[-2] in metric_names):
        scores = df.get(key[1], [])
        scores.append(man.metrics[key])
        df[key[1]] = scores
        
df0 = pd.DataFrame(df, index=[f'WMT14 De-En, {m}, PRR' for m in metric_names])  
df0.T.sort_values(f"WMT14 De-En, {metric_names[-1]}, PRR", ascending=False).style.background_gradient(axis=0)
# Out:
# Stat calculators: [<lm_polygraph.stat_calculators.greedy_probs.GreedyProbsCalculator object at 0x7fc48b67cf40>]
# <style type="text/css">
# #T_5b311_row0_col0 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_5b311_row0_col1, #T_5b311_row5_col0, #T_5b311_row6_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_5b311_row1_col0, #T_5b311_row9_col1, #T_5b311_row10_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_5b311_row1_col1 {
#   background-color: #045280;
#   color: #f1f1f1;
# }
# #T_5b311_row2_col0 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_5b311_row2_col1 {
#   background-color: #045382;
#   color: #f1f1f1;
# }
# #T_5b311_row3_col0, #T_5b311_row4_col0 {
#   background-color: #02395a;
#   color: #f1f1f1;
# }
# #T_5b311_row3_col1, #T_5b311_row4_col1, #T_5b311_row5_col1, #T_5b311_row6_col1 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_5b311_row7_col0 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_5b311_row7_col1, #T_5b311_row8_col1 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_5b311_row8_col0 {
#   background-color: #65a3cb;
#   color: #f1f1f1;
# }
# #T_5b311_row9_col0 {
#   background-color: #328dbf;
#   color: #f1f1f1;
# }
# #T_5b311_row10_col0 {
#   background-color: #2f8bbe;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5b311">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5b311_level0_col0" class="col_heading level0 col0" >WMT14 De-En, Comet, PRR</th>
#       <th id="T_5b311_level0_col1" class="col_heading level0 col1" >WMT14 De-En, AlignScore, PRR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b311_level0_row0" class="row_heading level0 row0" >MeanTokenEntropy</th>
#       <td id="T_5b311_row0_col0" class="data row0 col0" >0.008118</td>
#       <td id="T_5b311_row0_col1" class="data row0 col1" >0.100074</td>
#     </tr>
#     <tr>
#       <th id="T_5b311_level0_row1" class="row_heading level0 row1" >MaximumSequenceProbability</th>
#       <td id="T_5b311_row1_col0" class="data row1 col0" >-0.027159</td>
#       <td id="T_5b311_row1_col1" class="data row1 col1" >0.033613</td>
#     </tr>
#     <tr>
#       <th id="T_5b311_level0_row2" class="row_heading level0 row2" >Perplexity</th>
#       <td id="T_5b311_row2_col0" class="data row2 col0" >-0.022617</td>
#       <td id="T_5b311_row2_col1" class="data row2 col1" >0.029431</td>
#     </tr>
#     <tr>
#       <th id="T_5b311_level0_row3" class="row_heading level0 row3" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.0)</th>
#       <td id="T_5b311_row3_col0" class="data row3 col0" >0.174806</td>
#       <td id="T_5b311_row3_col1" class="data row3 col1" >-0.557457</td>
#     </tr>
#     <tr>
#       <th id="T_5b311_level0_row4" class="row_heading level0 row4" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_5b311_row4_col0" class="data row4 col0" >0.174661</td>
#       <td id="T_5b311_row4_col1" class="data row4 col1" >-0.557478</td>
#     </tr>
#     <tr>
#       <th id="T_5b311_level0_row5" class="row_heading level0 row5" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_5b311_row5_col0" class="data row5 col0" >0.175602</td>
#       <td id="T_5b311_row5_col1" class="data row5 col1" >-0.559307</td>
#     </tr>
#     <tr>
#       <th id="T_5b311_level0_row6" class="row_heading level0 row6" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_5b311_row6_col0" class="data row6 col0" >0.175552</td>
#       <td id="T_5b311_row6_col1" class="data row6 col1" >-0.559364</td>
#     </tr>
#     <tr>
#       <th id="T_5b311_level0_row7" class="row_heading level0 row7" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.0)</th>
#       <td id="T_5b311_row7_col0" class="data row7 col0" >0.077897</td>
#       <td id="T_5b311_row7_col1" class="data row7 col1" >-0.568182</td>
#     </tr>
#     <tr>
#       <th id="T_5b311_level0_row8" class="row_heading level0 row8" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_5b311_row8_col0" class="data row8 col0" >0.080204</td>
#       <td id="T_5b311_row8_col1" class="data row8 col1" >-0.569053</td>
#     </tr>
#     <tr>
#       <th id="T_5b311_level0_row9" class="row_heading level0 row9" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_5b311_row9_col0" class="data row9 col0" >0.101214</td>
#       <td id="T_5b311_row9_col1" class="data row9 col1" >-0.596230</td>
#     </tr>
#     <tr>
#       <th id="T_5b311_level0_row10" class="row_heading level0 row10" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_5b311_row10_col0" class="data row10 col0" >0.103366</td>
#       <td id="T_5b311_row10_col1" class="data row10 col1" >-0.596771</td>
#     </tr>
#   </tbody>
# </table>

# %%
np.mean(man.gen_metrics[('sequence', 'Comet')])
# Out:
# 0.5119356378316879

# %% [markdown]
# ## Stablm 12b

# %%
path = "lm-polygraph/workdir/output/nmt/stabilityai/stablelm-2-12b/['wmt14', 'de-en']/2024-04-10/05-39-15/ue_manager_seed1"
man = UEManager.load(path)

metric_names = ['Comet', 'AlignScore']
df = {}
for key in man.metrics.keys():
    if (key[-1] == 'prr_normalized') and (key[-2] in metric_names):
        scores = df.get(key[1], [])
        scores.append(man.metrics[key])
        df[key[1]] = scores
        
df0 = pd.DataFrame(df, index=[f'WMT14 De-En, {m}, PRR' for m in metric_names])  
df0.T.sort_values(f"WMT14 De-En, {metric_names[-1]}, PRR", ascending=False).style.background_gradient(axis=0)
# Out:
# Stat calculators: [<lm_polygraph.stat_calculators.greedy_probs.GreedyProbsCalculator object at 0x7fc48b67cf40>]
# <style type="text/css">
# #T_d20a5_row0_col0, #T_d20a5_row0_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_d20a5_row1_col0 {
#   background-color: #034e7b;
#   color: #f1f1f1;
# }
# #T_d20a5_row1_col1 {
#   background-color: #03517e;
#   color: #f1f1f1;
# }
# #T_d20a5_row2_col0 {
#   background-color: #034a74;
#   color: #f1f1f1;
# }
# #T_d20a5_row2_col1 {
#   background-color: #045280;
#   color: #f1f1f1;
# }
# #T_d20a5_row3_col0, #T_d20a5_row4_col0, #T_d20a5_row10_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_d20a5_row3_col1, #T_d20a5_row4_col1 {
#   background-color: #04649d;
#   color: #f1f1f1;
# }
# #T_d20a5_row5_col0 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_d20a5_row5_col1 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_d20a5_row6_col0 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_d20a5_row6_col1 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_d20a5_row7_col0, #T_d20a5_row8_col0 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_d20a5_row7_col1 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_d20a5_row8_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_d20a5_row9_col0 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_d20a5_row9_col1 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_d20a5_row10_col0 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# </style>
# <table id="T_d20a5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d20a5_level0_col0" class="col_heading level0 col0" >WMT14 De-En, Comet, PRR</th>
#       <th id="T_d20a5_level0_col1" class="col_heading level0 col1" >WMT14 De-En, AlignScore, PRR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d20a5_level0_row0" class="row_heading level0 row0" >MaximumSequenceProbability</th>
#       <td id="T_d20a5_row0_col0" class="data row0 col0" >0.262681</td>
#       <td id="T_d20a5_row0_col1" class="data row0 col1" >0.729212</td>
#     </tr>
#     <tr>
#       <th id="T_d20a5_level0_row1" class="row_heading level0 row1" >MeanTokenEntropy</th>
#       <td id="T_d20a5_row1_col0" class="data row1 col0" >0.247645</td>
#       <td id="T_d20a5_row1_col1" class="data row1 col1" >0.587531</td>
#     </tr>
#     <tr>
#       <th id="T_d20a5_level0_row2" class="row_heading level0 row2" >Perplexity</th>
#       <td id="T_d20a5_row2_col0" class="data row2 col0" >0.249943</td>
#       <td id="T_d20a5_row2_col1" class="data row2 col1" >0.579881</td>
#     </tr>
#     <tr>
#       <th id="T_d20a5_level0_row3" class="row_heading level0 row3" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_d20a5_row3_col0" class="data row3 col0" >0.080823</td>
#       <td id="T_d20a5_row3_col1" class="data row3 col1" >0.449890</td>
#     </tr>
#     <tr>
#       <th id="T_d20a5_level0_row4" class="row_heading level0 row4" >TokenMahalanobisDistance_decoder (sum, alignscore, 0.0)</th>
#       <td id="T_d20a5_row4_col0" class="data row4 col0" >0.080889</td>
#       <td id="T_d20a5_row4_col1" class="data row4 col1" >0.449403</td>
#     </tr>
#     <tr>
#       <th id="T_d20a5_level0_row5" class="row_heading level0 row5" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_d20a5_row5_col0" class="data row5 col0" >0.156284</td>
#       <td id="T_d20a5_row5_col1" class="data row5 col1" >0.016247</td>
#     </tr>
#     <tr>
#       <th id="T_d20a5_level0_row6" class="row_heading level0 row6" >TokenMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_d20a5_row6_col0" class="data row6 col0" >0.147046</td>
#       <td id="T_d20a5_row6_col1" class="data row6 col1" >-0.058706</td>
#     </tr>
#     <tr>
#       <th id="T_d20a5_level0_row7" class="row_heading level0 row7" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.5)</th>
#       <td id="T_d20a5_row7_col0" class="data row7 col0" >0.123638</td>
#       <td id="T_d20a5_row7_col1" class="data row7 col1" >-0.625219</td>
#     </tr>
#     <tr>
#       <th id="T_d20a5_level0_row8" class="row_heading level0 row8" >RelativeMahalanobisDistance_decoder (mean, alignscore, 0.0)</th>
#       <td id="T_d20a5_row8_col0" class="data row8 col0" >0.123479</td>
#       <td id="T_d20a5_row8_col1" class="data row8 col1" >-0.649622</td>
#     </tr>
#     <tr>
#       <th id="T_d20a5_level0_row9" class="row_heading level0 row9" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.5)</th>
#       <td id="T_d20a5_row9_col0" class="data row9 col0" >0.097356</td>
#       <td id="T_d20a5_row9_col1" class="data row9 col1" >-0.761433</td>
#     </tr>
#     <tr>
#       <th id="T_d20a5_level0_row10" class="row_heading level0 row10" >RelativeMahalanobisDistance_decoder (sum, alignscore, 0.0)</th>
#       <td id="T_d20a5_row10_col0" class="data row10 col0" >0.092805</td>
#       <td id="T_d20a5_row10_col1" class="data row10 col1" >-0.812065</td>
#     </tr>
#   </tbody>
# </table>

# %%
np.mean(man.gen_metrics[('sequence', 'Comet')])
# Out:
# 0.822441279232502
